# %% [markdown]
# <title>Capstone Project</title>

# %% [markdown]
# <title>Capstone - Data Science</title>

# %% [markdown]
# <h1>Analysis of Neighborhoods and Boroughs in Toronto, Canada for trending venues.</h1>

# %% [markdown]
# <h3>IBM Data Science Professional - Coursera Specialization</h3>

# %% [markdown]
# <h4>Import <i>Pandas</i> and <i>Numpy</i> libraries</h4>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h2> Part 1: Data Scraping and Wrangling</h2>

# %% [markdown]
# <h4>Install the libraries needed for the web scraping exercise</h4>

# %%
# !pip install requests
# !pip install bs4
# !pip install plotly
# Out:
# Requirement already satisfied: requests in e:\anaconda\lib\site-packages (2.22.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in e:\anaconda\lib\site-packages (from requests) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in e:\anaconda\lib\site-packages (from requests) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in e:\anaconda\lib\site-packages (from requests) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in e:\anaconda\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: bs4 in e:\anaconda\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in e:\anaconda\lib\site-packages (from bs4) (4.7.1)
# Requirement already satisfied: soupsieve>=1.2 in e:\anaconda\lib\site-packages (from beautifulsoup4->bs4) (1.8)
# Requirement already satisfied: plotly in e:\anaconda\lib\site-packages (5.1.0)
# Requirement already satisfied: six in e:\anaconda\lib\site-packages (from plotly) (1.12.0)
# Requirement already satisfied: tenacity>=6.2.0 in e:\anaconda\lib\site-packages (from plotly) (8.0.1)

# %% [markdown]
# <h4>Import the libraries needed for the web scraping exercise</h4>

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# <h4>Utilize the <i>requests</i> library to download the Wikipedia Page</h4>

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
response=requests.get(url)
html_data=response.content

# %% [markdown]
# <h4>Parse the html using <i>beautiful soup</i></h4>

# %%
soup = BeautifulSoup(html_data)

# %% [markdown]
# <h4>Create a list to store table data</h4>

# %%
table_contents=[]

# %% [markdown]
# <h4>Extract the table from the html containing the attributes: PostalCode, Borough and Neighborhood</h4>

# %%
table=soup.find('table')
for row in table.findAll('td'):
    cell = {}
    if row.span.text=='Not assigned':
        pass
    else:
        cell['PostalCode'] = row.p.text[:3]
        cell['Borough'] = (row.span.text).split('(')[0]
        cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ')
        table_contents.append(cell)

# %% [markdown]
# <h4>Store the extracted table contents into a dataframe</h4>

# %%
df=pd.DataFrame(table_contents)
df['Borough']=df['Borough'].replace({'Downtown TorontoStn A PO Boxes25 The Esplanade':'Downtown Toronto Stn A',
                                             'East TorontoBusiness reply mail Processing Centre969 Eastern':'East Toronto Business',
                                             'EtobicokeNorthwest':'Etobicoke Northwest','East YorkEast Toronto':'East York/East Toronto',
                                             'MississaugaCanada Post Gateway Processing Centre':'Mississauga'})

# %% [markdown]
# <h4>Display the first 5 rows of the dataframe to check for values</h4>

# %%
df.head()
# Out:
#             Borough                      Neighborhood PostalCode
# 0        North York                         Parkwoods        M3A
# 1        North York                  Victoria Village        M4A
# 2  Downtown Toronto         Regent Park, Harbourfront        M5A
# 3        North York  Lawrence Manor, Lawrence Heights        M6A
# 4      Queen's Park     Ontario Provincial Government        M7A

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# <h2>Part 2: Geospatial Analysis</h2>

# %% [markdown]
# <h3>2.1: Determine the longitude and latitude of the Postal Codes</h3>

# %% [markdown]
# <h3>Install and import the <i>Geocoder</i> python package</h3>

# %%
# !pip install geocoder
# Out:
# Requirement already satisfied: geocoder in e:\anaconda\lib\site-packages (1.38.1)
# Requirement already satisfied: requests in e:\anaconda\lib\site-packages (from geocoder) (2.22.0)
# Requirement already satisfied: six in e:\anaconda\lib\site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: click in e:\anaconda\lib\site-packages (from geocoder) (7.0)
# Requirement already satisfied: future in e:\anaconda\lib\site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: ratelim in e:\anaconda\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in e:\anaconda\lib\site-packages (from requests->geocoder) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in e:\anaconda\lib\site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in e:\anaconda\lib\site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in e:\anaconda\lib\site-packages (from requests->geocoder) (2019.6.16)
# Requirement already satisfied: decorator in e:\anaconda\lib\site-packages (from ratelim->geocoder) (4.4.0)

# %%
import geocoder

# %% [markdown]
# <h4>Initialize the Geo variables to none</h4>

# %%
lat_lng_coords = None

# %% [markdown]
# <h4>Loop until we obtain the Geo coordinates</h4>

# %%
#Due to common errors with this package, a CSV file with the values pre-defined will be utilized instead
#while(lat_lng_coords is None):
#  g = geocoder.google('{}, Toronto, Ontario')
#  lat_lng_coords = g.latlng
#
#latitude = lat_lng_coords[0]
#longitude = lat_lng_coords[1]

# %% [markdown]
# <h4>Utilizing a CSV file with the files pre-defined</h4>

# %%
Geo_file = 'C:\\Users\\hayth\\Downloads\\Geospatial_Coordinates.csv'
lat_lng_coord=pd.read_csv(Geo_file)
lat_lng_coord.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# <h4>Add the two columns to the original data frame</h4>

# %%
lat_lng_coord.rename(columns = {"Postal Code": "PostalCode"}, inplace=True) #Rename column in the Data Frame to match the naming with the original data frame and allow for the merging of the two data frames
main_df = pd.merge(df, lat_lng_coord, on='PostalCode')
main_df.head()
# Out:
#             Borough                      Neighborhood PostalCode   Latitude  \
# 0        North York                         Parkwoods        M3A  43.753259
# 1        North York                  Victoria Village        M4A  43.725882
# 2  Downtown Toronto         Regent Park, Harbourfront        M5A  43.654260
# 3        North York  Lawrence Manor, Lawrence Heights        M6A  43.718518
# 4      Queen's Park     Ontario Provincial Government        M7A  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %%
main_df.shape
# Out:
# (103, 5)

# %% [markdown]
# <h3>2.2: Connect to the Foursquare API</h3>

# %% [markdown]
# <h4>Note: This analysis replicate the analysis performed to the New York Data by selecting a specific location (borough) and exploring venues around the selected location.</h4>

# %% [markdown]
# <h4>Declare the Foursquare credentials and variables</h4>

# %%
CLIENT_ID = 'ZTLKNZCELC33KXINJUOXG2EDYQSGTRR5JPETP1DF4OTI3RMU' #Foursquare ID
CLIENT_SECRET = 'A5MSF4DLXAIEPYAJH5VKC52BPHFPLJ03UC4BJBVLVIRTMTSW' #Foursquare Secret
ACCESS_TOKEN = 'L33AUJG4MP4DRH0IUJNUNUFKZFEMCOEQ3QM4153GL1O0SAJK' #FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
radius = 500

# %% [markdown]
# <h3>2.3: Selecting Downtown Toronto borough in the Toronto dataframe and exploring venues around its location.</h3>

# %% [markdown]
# <h4>Select one of the boroughs in our Toronto dataframe</h4>

# %%
main_df.loc[2, 'Borough']
# Out:
# 'Downtown Toronto'

# %% [markdown]
# <h4>Determine the latitude and longitude values of the "Downtown Toronto" borough</h4>

# %%
latitude = main_df.loc[2, 'Latitude']
longitude = main_df.loc[2, 'Longitude']
print("The latitude and longitude of {} borough are respectively {} and {}.".format(main_df.loc[2, 'Borough'],
                                                                                    latitude,
                                                                                    longitude))
# Out:
# The latitude and longitude of Downtown Toronto borough are respectively 43.6542599 and -79.3606359.

# %%
#in case we need to specify a specific search query, we input our search parameter into this object and pass it to the below search URL
search = ''

# %% [markdown]
# <h4>Declare the Foursquare search URL as an object</h4>

# %%
search_url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, radius, LIMIT)

# %% [markdown]
# <h4>Receive the GET Request and examine the results from the declared URL</h4>

# %%
results = requests.get(search_url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60f6f5edf180a40a3d4bdc0e'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '5bdc6c2bba57b4002c4c71a8',
#     'name': 'Oldtown Bodega',
#     'location': {'lat': 43.653966,
#      'lng': -79.360752,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653966,
#        'lng': -79.360752}],
#      'distance': 34,
#      'postalCode': 'M5A 1L6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON M5A 1L6', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '4dc9d4d9d16495ca5add0803',
#     'name': "Cam's Auto Service",
#     'location': {'address': '475 King Street East',
#      'crossStreet': 'Sackville Street',
#      'lat': 43.65419500779484,
#      'lng': -79.3605451979777,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65419500779484,
#        'lng': -79.3605451979777}],
#      'distance': 10,
#      'postalCode': 'M4M 2T7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['475 King Street East (Sackville Street)',
#       'Toronto ON M4M 2T7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124951735',
#       'name': 'Automotive Shop',
#       'pluralName': 'Automotive Shops',
#       'shortName': 'Automotive',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '53b8466a498e83df908c3f21',
#     'name': 'Tandem Coffee',
#     'location': {'address': '368 King St E',
#      'crossStreet': 'at Trinity St',
#      'lat': 43.65355870959944,
#      'lng': -79.36180945913513,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65355870959944,
#        'lng': -79.36180945913513}],
#      'distance': 122,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['368 King St E (at Trinity St)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '5e3618557bde930007d18b8d',
#     'name': 'Gusto 501',
#     'location': {'address': '501 King St E',
#      'lat': 43.65481,
#      'lng': -79.359595,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65481,
#        'lng': -79.359595}],
#      'distance': 103,
#      'postalCode': 'M5A 1L9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['501 King St E', 'Toronto ON M5A 1L9', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '4d067a2b26adb1f702f9dc70',
#     'name': 'Thruway Muffler / Downtown Brake',
#     'location': {'address': '475 King St. E',
#      'lat': 43.654241672461424,
#      'lng': -79.36085318020055,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654241672461424,
#        'lng': -79.36085318020055}],
#      'distance': 17,
#      'postalCode': 'M5A 1L6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['475 King St. E', 'Toronto ON M5A 1L6', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '58e92e150319b80a65d8476c',
#     'name': 'Libbys Custom Framing',
#     'location': {'address': '465 King Street',
#      'lat': 43.654126,
#      'lng': -79.360682,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654126,
#        'lng': -79.360682}],
#      'distance': 15,
#      'postalCode': 'M5A 1L6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['465 King Street', 'Toronto ON M5A 1L6', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d127951735',
#       'name': 'Arts & Crafts Store',
#       'pluralName': 'Arts & Crafts Stores',
#       'shortName': 'Arts & Crafts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/artstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '5d266686f3c3c10023171ace',
#     'name': 'Hastings Barbershop Corktown',
#     'location': {'lat': 43.654175,
#      'lng': -79.36102,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654175,
#        'lng': -79.36102}],
#      'distance': 32,
#      'postalCode': 'M5A 1L4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON M5A 1L4', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '5d8d192fd2219e0008624db1',
#     'name': 'Bottē Gallery',
#     'location': {'address': '398 King st East',
#      'lat': 43.65411,
#      'lng': -79.360976,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65411,
#        'lng': -79.360976}],
#      'distance': 32,
#      'postalCode': 'M5A 1K9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['398 King st East', 'Toronto ON M5A 1K9', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '4b1951c1f964a5202edb23e3',
#     'name': 'King Deli Cafe',
#     'location': {'address': '465 King Street E',
#      'crossStreet': 'just East of Parliament St',
#      'lat': 43.65390613999999,
#      'lng': -79.361147,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65390613999999,
#        'lng': -79.361147}],
#      'distance': 56,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['465 King Street E (just East of Parliament St)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '4bc70f5d14d7952126a066e9',
#     'name': 'Sackville Playground',
#     'location': {'address': '420 king st E',
#      'lat': 43.65465604258614,
#      'lng': -79.35987064632435,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65465604258614,
#        'lng': -79.35987064632435}],
#      'distance': 75,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['420 king st E', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '5e5d749285a0610007e60fe8',
#     'name': 'Terroni Sud Forno Produzione e Spaccio',
#     'location': {'address': '22 Sackville St',
#      'lat': 43.653903,
#      'lng': -79.360018,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653903,
#        'lng': -79.360018}],
#      'distance': 63,
#      'postalCode': 'M5A 3E2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['22 Sackville St', 'Toronto ON M5A 3E2', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1f5941735',
#       'name': 'Gourmet Shop',
#       'pluralName': 'Gourmet Shops',
#       'shortName': 'Gourmet',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '5aad9b86fdb9a7176b2d50ac',
#     'name': 'Henrietta Lane',
#     'location': {'address': '394 King Street East',
#      'lat': 43.653911,
#      'lng': -79.361395,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653911,
#        'lng': -79.361395}],
#      'distance': 72,
#      'postalCode': 'M5A 1K9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['394 King Street East',
#       'Toronto ON M5A 1K9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d11e941735',
#       'name': 'Cocktail Bar',
#       'pluralName': 'Cocktail Bars',
#       'shortName': 'Cocktail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '4e02deac18389833c594fe1d',
#     'name': 'The Darkest Corner Of My Mind',
#     'location': {'lat': 43.654938,
#      'lng': -79.360975,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654938,
#        'lng': -79.360975}],
#      'distance': 80,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d12f941735',
#       'name': 'Library',
#       'pluralName': 'Libraries',
#       'shortName': 'Library',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '4ca1de8b46978cfabc64bf7f',
#     'name': '502 Queen Streetcar',
#     'location': {'address': 'via Kingston Rd',
#      'lat': 43.66001333517798,
#      'lng': -79.34475839138031,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66001333517798,
#        'lng': -79.34475839138031}],
#      'distance': 1430,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['via Kingston Rd', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fc931735',
#       'name': 'Light Rail Station',
#       'pluralName': 'Light Rail Stations',
#       'shortName': 'Light Rail',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '4dd27b4d227159fef24ba1c2',
#     'name': 'Volvo of Toronto',
#     'location': {'address': '43 Eastern Ave',
#      'lat': 43.652759709332685,
#      'lng': -79.36025435326364,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652759709332685,
#        'lng': -79.36025435326364}],
#      'distance': 169,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['43 Eastern Ave', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124951735',
#       'name': 'Automotive Shop',
#       'pluralName': 'Automotive Shops',
#       'shortName': 'Automotive',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '54248f4e498e455132a5cee7',
#     'name': 'Honda Downtown',
#     'location': {'address': '47 Eastern Avenue',
#      'lat': 43.65311455793185,
#      'lng': -79.35917026487203,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65311455793185,
#        'lng': -79.35917026487203}],
#      'distance': 173,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['47 Eastern Avenue', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124951735',
#       'name': 'Automotive Shop',
#       'pluralName': 'Automotive Shops',
#       'shortName': 'Automotive',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '4e54574bb61c93816c084ddb',
#     'name': "Orphan's Greenspace Dog Park",
#     'location': {'address': '51 Power St.',
#      'crossStreet': 'btwn Adelaide St. & Richmond Ave.',
#      'lat': 43.65465395413889,
#      'lng': -79.36250077861264,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65465395413889,
#        'lng': -79.36250077861264}],
#      'distance': 156,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['51 Power St. (btwn Adelaide St. & Richmond Ave.)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e5941735',
#       'name': 'Dog Run',
#       'pluralName': 'Dog Runs',
#       'shortName': 'Dog Run',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '5cd60624b9b37b002c47e8e3',
#     'name': 'Bar Reyna',
#     'location': {'address': '354 King St. E.',
#      'lat': 43.653446,
#      'lng': -79.36224,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653446,
#        'lng': -79.36224}],
#      'distance': 157,
#      'postalCode': 'M5A 1K9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['354 King St. E.', 'Toronto ON M5A 1K9', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c0941735',
#       'name': 'Mediterranean Restaurant',
#       'pluralName': 'Mediterranean Restaurants',
#       'shortName': 'Mediterranean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '5151c3fde4b02da132c9553e',
#     'name': 'Power Park Off- leash',
#     'location': {'lat': 43.654763,
#      'lng': -79.362408,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654763,
#        'lng': -79.362408}],
#      'distance': 153,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e5941735',
#       'name': 'Dog Run',
#       'pluralName': 'Dog Runs',
#       'shortName': 'Dog Run',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '4ad4c05ef964a5209bf620e3',
#     'name': 'The Beaches',
#     'location': {'address': 'Queen Street East',
#      'crossStreet': 'between Coxwell and Woodbine Avenue',
#      'lat': 43.652106879173516,
#      'lng': -79.3611721607108,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652106879173516,
#        'lng': -79.3611721607108}],
#      'distance': 243,
#      'postalCode': 'M4E 1C0',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Queen Street East (between Coxwell and Woodbine Avenue)',
#       'Toronto ON M4E 1C0',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d12d941735',
#       'name': 'Monument / Landmark',
#       'pluralName': 'Monuments / Landmarks',
#       'shortName': 'Landmark',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '4c61f84fedd320a1aafeab29',
#     'name': 'MASS LBP',
#     'location': {'address': '392A King St. E.',
#      'crossStreet': 'Trinity',
#      'lat': 43.65398407982623,
#      'lng': -79.36127007007599,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65398407982623,
#        'lng': -79.36127007007599}],
#      'distance': 59,
#      'postalCode': 'M5A 1K9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['392A King St. E. (Trinity)',
#       'Toronto ON M5A 1K9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '39686391'},
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '4e8b7fa1cc2112f67517660a',
#     'name': 'The Extension Room',
#     'location': {'address': '30 Eastern Ave',
#      'crossStreet': 'Sackville St.',
#      'lat': 43.65331304337331,
#      'lng': -79.35972538072777,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65331304337331,
#        'lng': -79.35972538072777}],
#      'distance': 128,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['30 Eastern Ave (Sackville St.)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '57b12ecf498e84b0379c079a',
#     'name': 'Face',
#     'location': {'lat': 43.65492,
#      'lng': -79.359371,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65492,
#        'lng': -79.359371}],
#      'distance': 125,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d166941735',
#       'name': 'Sculpture Garden',
#       'pluralName': 'Sculpture Gardens',
#       'shortName': 'Sculpture',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sculpture_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '576864be498e42995f045b4e',
#     'name': 'Orphan Black Police Station',
#     'location': {'address': '507 King Street East',
#      'lat': 43.655757,
#      'lng': -79.358012,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655757,
#        'lng': -79.358012}],
#      'distance': 269,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['507 King Street East', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b79ee',
#       'name': 'Street Art',
#       'pluralName': 'Street Art Installations',
#       'shortName': 'Street Art',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '4ca5fcd576d3a09316dcfc6a',
#     'name': 'Sherwin-Williams Paint Store',
#     'location': {'address': '423 Queen St E',
#      'crossStreet': 'Sackville St',
#      'lat': 43.65637195011159,
#      'lng': -79.36129315303127,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65637195011159,
#        'lng': -79.36129315303127}],
#      'distance': 240,
#      'postalCode': 'M5A 1T5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['423 Queen St E (Sackville St)',
#       'Toronto ON M5A 1T5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d112951735',
#       'name': 'Hardware Store',
#       'pluralName': 'Hardware Stores',
#       'shortName': 'Hardware',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '4beb288d62c0c928dcc8e1d4',
#     'name': 'Fresh Home and Garden',
#     'location': {'address': '16 Eastern Ave',
#      'crossStreet': 'Trinity',
#      'lat': 43.653152574922764,
#      'lng': -79.36066069143106,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653152574922764,
#        'lng': -79.36066069143106}],
#      'distance': 123,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['16 Eastern Ave (Trinity)', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1f8941735',
#       'name': 'Furniture / Home Store',
#       'pluralName': 'Furniture / Home Stores',
#       'shortName': 'Furniture / Home',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '4fa7ebe5a17c43f4427e572b',
#     'name': "Buster's Sea Cove Truck",
#     'location': {'lat': 43.65364665307943,
#      'lng': -79.35787780917855,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65364665307943,
#        'lng': -79.35787780917855}],
#      'distance': 232,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '574c229e498ebb5c6b257902',
#     'name': 'Cooper Koo Family YMCA',
#     'location': {'address': '461 Cherry St',
#      'lat': 43.65324910177244,
#      'lng': -79.35800826343677,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65324910177244,
#        'lng': -79.35800826343677}],
#      'distance': 239,
#      'postalCode': 'M5A 0H7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['461 Cherry St', 'Toronto ON M5A 0H7', 'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a37',
#       'name': 'Distribution Center',
#       'pluralName': 'Distribution Centers',
#       'shortName': 'Distributor',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '4c45addf429a0f47b16b4a1e',
#     'name': 'Bay Cat Hospital',
#     'location': {'address': '525 King St East',
#      'lat': 43.655393,
#      'lng': -79.35854,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655393,
#        'lng': -79.35854}],
#      'distance': 210,
#      'cc': 'CA',
#      'city': 'Toronto Division',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['525 King St East',
#       'Toronto Division ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d196941735',
#       'name': 'Hospital',
#       'pluralName': 'Hospitals',
#       'shortName': 'Hospital',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False},
#    {'id': '50760559e4b0e8c7babe2497',
#     'name': 'Body Blitz Spa East',
#     'location': {'address': '497 King Street East',
#      'crossStreet': 'btwn Sackville St and Sumach St',
#      'lat': 43.65473505045365,
#      'lng': -79.35987433132891,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65473505045365,
#        'lng': -79.35987433132891}],
#      'distance': 80,
#      'postalCode': 'M5A 1L9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['497 King Street East (btwn Sackville St and Sumach St)',
#       'Toronto ON M5A 1L9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ed941735',
#       'name': 'Spa',
#       'pluralName': 'Spas',
#       'shortName': 'Spa',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1626797549',
#     'hasPerk': False}],
#   'confident': False}}

# %% [markdown]
# <h4>The below function streamlines the process for getting the relevant part of the received JSON for any neighborhoud</h4>

# %%
def get_venues(neighborhood, lat, long, limit=100, radius=250):
    params = dict(
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET,
        v=VERSION,
        ll=f"{lat}, {long}",
        radius=radius,
        limit=limit
    )
    venues = []
    data = requests.get(url=search_url, params=params).json()
    for v in data['response']['venues']:
        venues.append([neighborhood, lat, long, v['name'], v['location']['lat'], v['location']['lng']])
    return venues

# %%
#get_venues('North York', 43.7532586, -79.3296565)

# %% [markdown]
# <h4>Obtain the relevant part of the JSON of the declared URL</h4>

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# %% [markdown]
# <h4>Transform the relevant JSON venues list into a dataframe</h4>

# %%
# import the library that allows tranforming json files into a pandas dataframe library
from pandas.io.json import json_normalize


# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 1  [{'id': '4bf58dd8d48988d124951735', 'name': 'A...    False
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 4  [{'id': '4bf58dd8d48988d130941735', 'name': 'B...    False
#
#                          id      location.address location.cc location.city  \
# 0  5bdc6c2bba57b4002c4c71a8                   NaN          CA       Toronto
# 1  4dc9d4d9d16495ca5add0803  475 King Street East          CA       Toronto
# 2  53b8466a498e83df908c3f21         368 King St E          CA       Toronto
# 3  5e3618557bde930007d18b8d         501 King St E          CA       Toronto
# 4  4d067a2b26adb1f702f9dc70        475 King St. E          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada                  NaN                 34
# 1           Canada     Sackville Street                 10
# 2           Canada        at Trinity St                122
# 3           Canada                  NaN                103
# 4           Canada                  NaN                 17
#
#                            location.formattedAddress  \
# 0                       [Toronto ON M5A 1L6, Canada]
# 1  [475 King Street East (Sackville Street), Toro...
# 2  [368 King St E (at Trinity St), Toronto ON, Ca...
# 3        [501 King St E, Toronto ON M5A 1L9, Canada]
# 4       [475 King St. E, Toronto ON M5A 1L6, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.653966, 'lng':...     43.653966
# 1  [{'label': 'display', 'lat': 43.65419500779484...     43.654195
# 2  [{'label': 'display', 'lat': 43.65355870959944...     43.653559
# 3  [{'label': 'display', 'lat': 43.65481, 'lng': ...     43.654810
# 4  [{'label': 'display', 'lat': 43.65424167246142...     43.654242
#
#    location.lng location.postalCode location.state  \
# 0    -79.360752             M5A 1L6             ON
# 1    -79.360545             M4M 2T7             ON
# 2    -79.361809                 NaN             ON
# 3    -79.359595             M5A 1L9             ON
# 4    -79.360853             M5A 1L6             ON
#
#                                name    referralId venuePage.id
# 0                    Oldtown Bodega  v-1626797549          NaN
# 1                Cam's Auto Service  v-1626797549          NaN
# 2                     Tandem Coffee  v-1626797549          NaN
# 3                         Gusto 501  v-1626797549          NaN
# 4  Thruway Muffler / Downtown Brake  v-1626797549          NaN

# %% [markdown]
# <h4>Filter dataframe according to informaiton of interest.</h4>

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                                name          categories               address  \
# 0                    Oldtown Bodega                Café                   NaN
# 1                Cam's Auto Service     Automotive Shop  475 King Street East
# 2                     Tandem Coffee         Coffee Shop         368 King St E
# 3                         Gusto 501  Italian Restaurant         501 King St E
# 4  Thruway Muffler / Downtown Brake            Building        475 King St. E
#
#    cc     city country       crossStreet  distance  \
# 0  CA  Toronto  Canada               NaN        34
# 1  CA  Toronto  Canada  Sackville Street        10
# 2  CA  Toronto  Canada     at Trinity St       122
# 3  CA  Toronto  Canada               NaN       103
# 4  CA  Toronto  Canada               NaN        17
#
#                                     formattedAddress  \
# 0                       [Toronto ON M5A 1L6, Canada]
# 1  [475 King Street East (Sackville Street), Toro...
# 2  [368 King St E (at Trinity St), Toronto ON, Ca...
# 3        [501 King St E, Toronto ON M5A 1L9, Canada]
# 4       [475 King St. E, Toronto ON M5A 1L6, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.653966, 'lng':...  43.653966 -79.360752
# 1  [{'label': 'display', 'lat': 43.65419500779484...  43.654195 -79.360545
# 2  [{'label': 'display', 'lat': 43.65355870959944...  43.653559 -79.361809
# 3  [{'label': 'display', 'lat': 43.65481, 'lng': ...  43.654810 -79.359595
# 4  [{'label': 'display', 'lat': 43.65424167246142...  43.654242 -79.360853
#
#   postalCode state                        id
# 0    M5A 1L6    ON  5bdc6c2bba57b4002c4c71a8
# 1    M4M 2T7    ON  4dc9d4d9d16495ca5add0803
# 2        NaN    ON  53b8466a498e83df908c3f21
# 3    M5A 1L9    ON  5e3618557bde930007d18b8d
# 4    M5A 1L6    ON  4d067a2b26adb1f702f9dc70

# %% [markdown]
# <h4>Create a new dataframe showing the data we only need (further filtering)</h4>

# %%
main_filtered = dataframe_filtered.drop(['country', 'crossStreet', 'labeledLatLngs', 'state', 'id'], axis=1)
main_filtered.head()
# Out:
#                                name          categories               address  \
# 0                    Oldtown Bodega                Café                   NaN
# 1                Cam's Auto Service     Automotive Shop  475 King Street East
# 2                     Tandem Coffee         Coffee Shop         368 King St E
# 3                         Gusto 501  Italian Restaurant         501 King St E
# 4  Thruway Muffler / Downtown Brake            Building        475 King St. E
#
#    cc     city  distance                                   formattedAddress  \
# 0  CA  Toronto        34                       [Toronto ON M5A 1L6, Canada]
# 1  CA  Toronto        10  [475 King Street East (Sackville Street), Toro...
# 2  CA  Toronto       122  [368 King St E (at Trinity St), Toronto ON, Ca...
# 3  CA  Toronto       103        [501 King St E, Toronto ON M5A 1L9, Canada]
# 4  CA  Toronto        17       [475 King St. E, Toronto ON M5A 1L6, Canada]
#
#          lat        lng postalCode
# 0  43.653966 -79.360752    M5A 1L6
# 1  43.654195 -79.360545    M4M 2T7
# 2  43.653559 -79.361809        NaN
# 3  43.654810 -79.359595    M5A 1L9
# 4  43.654242 -79.360853    M5A 1L6

# %% [markdown]
# <h4>Since we have limited number of request quota on Foursquare free tier, we will save the dataframe to a csv file, so that we can continue from here at a later point in time, if we need to close the notebook.

# %%
main_filtered.to_csv('toronto_boroughs_and_venues.csv')

# %% [markdown]
# <h3>2.4: Explore and visualize the venue data on a map (GIS)

# %% [markdown]
# <h4>Read the CSV and drop unnamed entries

# %%
main_T = pd.read_csv('toronto_boroughs_and_venues.csv')
main_T.drop(['Unnamed: 0'], axis=1, inplace=True)
main_T.head()
# Out:
#                                name          categories               address  \
# 0                    Oldtown Bodega                Café                   NaN
# 1                Cam's Auto Service     Automotive Shop  475 King Street East
# 2                     Tandem Coffee         Coffee Shop         368 King St E
# 3                         Gusto 501  Italian Restaurant         501 King St E
# 4  Thruway Muffler / Downtown Brake            Building        475 King St. E
#
#    cc     city  distance                                   formattedAddress  \
# 0  CA  Toronto        34                   ['Toronto ON M5A 1L6', 'Canada']
# 1  CA  Toronto        10  ['475 King Street East (Sackville Street)', 'T...
# 2  CA  Toronto       122  ['368 King St E (at Trinity St)', 'Toronto ON'...
# 3  CA  Toronto       103  ['501 King St E', 'Toronto ON M5A 1L9', 'Canada']
# 4  CA  Toronto        17  ['475 King St. E', 'Toronto ON M5A 1L6', 'Cana...
#
#          lat        lng postalCode
# 0  43.653966 -79.360752    M5A 1L6
# 1  43.654195 -79.360545    M4M 2T7
# 2  43.653559 -79.361809        NaN
# 3  43.654810 -79.359595    M5A 1L9
# 4  43.654242 -79.360853    M5A 1L6

# %%
#If we need to Keep only the rows with Toronto as city
main_T[main_T['city'] == 'Toronto']
# Out:
#                                       name                categories  \
# 0                           Oldtown Bodega                      Café
# 1                       Cam's Auto Service           Automotive Shop
# 2                            Tandem Coffee               Coffee Shop
# 3                                Gusto 501        Italian Restaurant
# 4         Thruway Muffler / Downtown Brake                  Building
# 5                    Libbys Custom Framing       Arts & Crafts Store
# 6             Hastings Barbershop Corktown        Salon / Barbershop
# 7                            Bottē Gallery               Art Gallery
# 8                           King Deli Cafe            Sandwich Place
# 9                     Sackville Playground                      Park
# 10  Terroni Sud Forno Produzione e Spaccio              Gourmet Shop
# 11                          Henrietta Lane              Cocktail Bar
# 12           The Darkest Corner Of My Mind                   Library
# 13                     502 Queen Streetcar        Light Rail Station
# 14                        Volvo of Toronto           Automotive Shop
# 15                          Honda Downtown           Automotive Shop
# 16            Orphan's Greenspace Dog Park                   Dog Run
# 17                               Bar Reyna  Mediterranean Restaurant
# 19                             The Beaches       Monument / Landmark
# 20                                MASS LBP                    Office
# 21                      The Extension Room      Gym / Fitness Center
# 23             Orphan Black Police Station                Street Art
# 24            Sherwin-Williams Paint Store            Hardware Store
# 25                   Fresh Home and Garden    Furniture / Home Store
# 26                 Buster's Sea Cove Truck                Food Truck
# 27                  Cooper Koo Family YMCA       Distribution Center
# 29                     Body Blitz Spa East                       Spa
#
#                  address  cc     city  distance  \
# 0                    NaN  CA  Toronto        34
# 1   475 King Street East  CA  Toronto        10
# 2          368 King St E  CA  Toronto       122
# 3          501 King St E  CA  Toronto       103
# 4         475 King St. E  CA  Toronto        17
# 5        465 King Street  CA  Toronto        15
# 6                    NaN  CA  Toronto        32
# 7       398 King st East  CA  Toronto        32
# 8      465 King Street E  CA  Toronto        56
# 9          420 king st E  CA  Toronto        75
# 10       22 Sackville St  CA  Toronto        63
# 11  394 King Street East  CA  Toronto        72
# 12                   NaN  CA  Toronto        80
# 13       via Kingston Rd  CA  Toronto      1430
# 14        43 Eastern Ave  CA  Toronto       169
# 15     47 Eastern Avenue  CA  Toronto       173
# 16          51 Power St.  CA  Toronto       156
# 17       354 King St. E.  CA  Toronto       157
# 19     Queen Street East  CA  Toronto       243
# 20      392A King St. E.  CA  Toronto        59
# 21        30 Eastern Ave  CA  Toronto       128
# 23  507 King Street East  CA  Toronto       269
# 24        423 Queen St E  CA  Toronto       240
# 25        16 Eastern Ave  CA  Toronto       123
# 26                   NaN  CA  Toronto       232
# 27         461 Cherry St  CA  Toronto       239
# 29  497 King Street East  CA  Toronto        80
#
#                                      formattedAddress        lat        lng  \
# 0                    ['Toronto ON M5A 1L6', 'Canada']  43.653966 -79.360752
# 1   ['475 King Street East (Sackville Street)', 'T...  43.654195 -79.360545
# 2   ['368 King St E (at Trinity St)', 'Toronto ON'...  43.653559 -79.361809
# 3   ['501 King St E', 'Toronto ON M5A 1L9', 'Canada']  43.654810 -79.359595
# 4   ['475 King St. E', 'Toronto ON M5A 1L6', 'Cana...  43.654242 -79.360853
# 5   ['465 King Street', 'Toronto ON M5A 1L6', 'Can...  43.654126 -79.360682
# 6                    ['Toronto ON M5A 1L4', 'Canada']  43.654175 -79.361020
# 7   ['398 King st East', 'Toronto ON M5A 1K9', 'Ca...  43.654110 -79.360976
# 8   ['465 King Street E (just East of Parliament S...  43.653906 -79.361147
# 9           ['420 king st E', 'Toronto ON', 'Canada']  43.654656 -79.359871
# 10  ['22 Sackville St', 'Toronto ON M5A 3E2', 'Can...  43.653903 -79.360018
# 11  ['394 King Street East', 'Toronto ON M5A 1K9',...  43.653911 -79.361395
# 12                           ['Toronto ON', 'Canada']  43.654938 -79.360975
# 13        ['via Kingston Rd', 'Toronto ON', 'Canada']  43.660013 -79.344758
# 14         ['43 Eastern Ave', 'Toronto ON', 'Canada']  43.652760 -79.360254
# 15      ['47 Eastern Avenue', 'Toronto ON', 'Canada']  43.653115 -79.359170
# 16  ['51 Power St. (btwn Adelaide St. & Richmond A...  43.654654 -79.362501
# 17  ['354 King St. E.', 'Toronto ON M5A 1K9', 'Can...  43.653446 -79.362240
# 19  ['Queen Street East (between Coxwell and Woodb...  43.652107 -79.361172
# 20  ['392A King St. E. (Trinity)', 'Toronto ON M5A...  43.653984 -79.361270
# 21  ['30 Eastern Ave (Sackville St.)', 'Toronto ON...  43.653313 -79.359725
# 23   ['507 King Street East', 'Toronto ON', 'Canada']  43.655757 -79.358012
# 24  ['423 Queen St E (Sackville St)', 'Toronto ON ...  43.656372 -79.361293
# 25  ['16 Eastern Ave (Trinity)', 'Toronto ON', 'Ca...  43.653153 -79.360661
# 26                           ['Toronto ON', 'Canada']  43.653647 -79.357878
# 27  ['461 Cherry St', 'Toronto ON M5A 0H7', 'Canada']  43.653249 -79.358008
# 29  ['497 King Street East (btwn Sackville St and ...  43.654735 -79.359874
#
#    postalCode
# 0     M5A 1L6
# 1     M4M 2T7
# 2         NaN
# 3     M5A 1L9
# 4     M5A 1L6
# 5     M5A 1L6
# 6     M5A 1L4
# 7     M5A 1K9
# 8         NaN
# 9         NaN
# 10    M5A 3E2
# 11    M5A 1K9
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17    M5A 1K9
# 19    M4E 1C0
# 20    M5A 1K9
# 21        NaN
# 23        NaN
# 24    M5A 1T5
# 25        NaN
# 26        NaN
# 27    M5A 0H7
# 29    M5A 1L9

# %% [markdown]
# <h4>Visualize the findings on a map

# %%
! pip install folium==0.5.0
import folium # plotting library

print('Folium installed and imported')
# Out:
# Requirement already satisfied: folium==0.5.0 in e:\anaconda\lib\site-packages (0.5.0)
# Requirement already satisfied: requests in e:\anaconda\lib\site-packages (from folium==0.5.0) (2.22.0)
# Requirement already satisfied: branca in e:\anaconda\lib\site-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: jinja2 in e:\anaconda\lib\site-packages (from folium==0.5.0) (2.10.1)
# Requirement already satisfied: six in e:\anaconda\lib\site-packages (from folium==0.5.0) (1.12.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in e:\anaconda\lib\site-packages (from requests->folium==0.5.0) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in e:\anaconda\lib\site-packages (from requests->folium==0.5.0) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in e:\anaconda\lib\site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in e:\anaconda\lib\site-packages (from requests->folium==0.5.0) (2019.6.16)
# Requirement already satisfied: MarkupSafe>=0.23 in e:\anaconda\lib\site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Folium installed and imported

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=20) # generate map centred around Downtown Toronto

# add Downtown Toronto as a red circle mark
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Downtown Toronto',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(main_T.lat, main_T.lng, main_T.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)
    
# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_714a8cbf17c449e28df75f3222504094%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_714a8cbf17c449e28df75f3222504094%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_714a8cbf17c449e28df75f3222504094%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_714a8cbf17c449e28df75f3222504094%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.6542599%2C-79.3606359%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2020%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# <h4>Instead of just exploring the venues around the defined location (Downtown Toronto), we want to explore the TRENDING VENUES around this location. Let's check for food venues.

# %% [markdown]
# <h4>Define a new URL to the Foursquare API with the parameter "trending"

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60f6f5f32222750a72e41e96'},
#  'response': {'venues': []}}

# %% [markdown]
# <h4>Check if any venues are trending at this time

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %% [markdown]
# <h4>Visualize the trending venues

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=20) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Downtown Toronto',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)
        
# display map
venues_map
# Out:
# 'Cannot generate visual as no trending venues are available at the moment!'

# %% [markdown]
# <h4>As can be seen, no trending venues are present at Downtown Toronto at this moment.

# %% [markdown]
# <h2>Part 3: Clustering via Machine Learning

# %% [markdown]
# There are many models for clustering. We will be utilizing <i>k-means</i> as it is vastly used for clustering in many data science applications, especially useful if we need to quickly discover insights from unlabeled data.

# %% [markdown]
# <h4>Import the <i>sklearn</i> library to import the <i>kmeans</i> library

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# <h4>Let's create a function to repeat the same process to all the neighborhoods in Manhattan

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# <h4>Utilize the abovementioned function

# %%
toronto_venues = getNearbyVenues(names=main_df['Neighborhood'],
                                   latitudes=main_df['Latitude'],
                                   longitudes=main_df['Longitude']
                                  )
# Out:
# Parkwoods
# Victoria Village
# Regent Park, Harbourfront
# Lawrence Manor, Lawrence Heights
# Ontario Provincial Government
# Islington Avenue
# Malvern, Rouge
# Don Mills North
# Parkview Hill, Woodbine Gardens
# Garden District, Ryerson
# Glencairn
# West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale
# Rouge Hill, Port Union, Highland Creek
# Don Mills South
# Woodbine Heights
# St. James Town
# Humewood-Cedarvale
# Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood
# Guildwood, Morningside, West Hill
# The Beaches
# Berczy Park
# Caledonia-Fairbanks
# Woburn
# Leaside
# Central Bay Street
# Christie
# Cedarbrae
# Hillcrest Village
# Bathurst Manor, Wilson Heights, Downsview North
# Thorncliffe Park
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Scarborough Village
# Fairview, Henry Farm, Oriole
# Northwood Park, York University
# The Danforth  East
# Harbourfront East, Union Station, Toronto Islands
# Little Portugal, Trinity
# Kennedy Park, Ionview, East Birchmount Park
# Bayview Village
# Downsview East
# The Danforth West, Riverdale
# Toronto Dominion Centre, Design Exchange
# Brockton, Parkdale Village, Exhibition Place
# Golden Mile, Clairlea, Oakridge
# York Mills, Silver Hills
# Downsview West
# India Bazaar, The Beaches West
# Commerce Court, Victoria Hotel
# North Park, Maple Leaf Park, Upwood Park
# Humber Summit
# Cliffside, Cliffcrest, Scarborough Village West
# Willowdale, Newtonbrook
# Downsview Central
# Studio District
# Bedford Park, Lawrence Manor East
# Del Ray, Mount Dennis, Keelsdale and Silverthorn
# Humberlea, Emery
# Birch Cliff, Cliffside West
# Willowdale South
# Downsview Northwest
# Lawrence Park
# Roselawn
# Runnymede, The Junction North
# Weston
# Dorset Park, Wexford Heights, Scarborough Town Centre
# York Mills West
# Davisville North
# Forest Hill North & West
# High Park, The Junction South
# Westmount
# Wexford, Maryvale
# Willowdale West
# North Toronto West
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Enclave of L4W
# Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens
# Agincourt
# Davisville
# University of Toronto, Harbord
# Runnymede, Swansea
# Clarks Corners, Tam O'Shanter, Sullivan
# Moore Park, Summerhill East
# Kensington Market, Chinatown, Grange Park
# Milliken, Agincourt North, Steeles East, L'Amoreaux East
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# New Toronto, Mimico South, Humber Bay Shores
# South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens
# Steeles West, L'Amoreaux West
# Rosedale
# Enclave of M5E
# Alderwood, Long Branch
# Clairville, Humberwood, Woodbine Downs, West Humber, Kipling Heights, Rexdale, Elms, Tandridge, Old Rexdale
# Upper Rouge
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# The Kingsway, Montgomery Road, Old Mill North
# Church and Wellesley
# Enclave of M4L
# Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East
# Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West

# %% [markdown]
# <h4>Let's check how many venues were returned for each neighborhood

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Agincourt                                                               5
# Alderwood, Long Branch                                                  7
# Bathurst Manor, Wilson Heights, Downsview North                        22
# Bayview Village                                                         4
# Bedford Park, Lawrence Manor East                                      25
# Berczy Park                                                            30
# Birch Cliff, Cliffside West                                             4
# Brockton, Parkdale Village, Exhibition Place                           23
# CN Tower, King and Spadina, Railway Lands, Harb...                     14
# Caledonia-Fairbanks                                                     4
# Cedarbrae                                                               8
# Central Bay Street                                                     30
# Christie                                                               16
# Church and Wellesley                                                   30
# Clairville, Humberwood, Woodbine Downs, West Hu...                      5
# Clarks Corners, Tam O'Shanter, Sullivan                                13
# Cliffside, Cliffcrest, Scarborough Village West                         3
# Commerce Court, Victoria Hotel                                         30
# Davisville                                                             30
# Davisville North                                                        7
# Del Ray, Mount Dennis, Keelsdale and Silverthorn                        4
# Don Mills North                                                         5
# Don Mills South                                                        21
# Dorset Park, Wexford Heights, Scarborough Town ...                      6
# Downsview Central                                                       2
# Downsview East                                                          2
# Downsview Northwest                                                     5
# Downsview West                                                          6
# Dufferin, Dovercourt Village                                           15
# Enclave of L4W                                                         13
# ...                                                                   ...
# Rouge Hill, Port Union, Highland Creek                                  2
# Runnymede, Swansea                                                     30
# Runnymede, The Junction North                                           5
# Scarborough Village                                                     2
# South Steeles, Silverstone, Humbergate, Jamesto...                     12
# St. James Town                                                         30
# St. James Town, Cabbagetown                                            30
# Steeles West, L'Amoreaux West                                          15
# Studio District                                                        30
# Summerhill West, Rathnelly, South Hill, Forest ...                     14
# The Annex, North Midtown, Yorkville                                    22
# The Beaches                                                             4
# The Danforth  East                                                      3
# The Danforth West, Riverdale                                           30
# The Kingsway, Montgomery Road, Old Mill North                           2
# Thorncliffe Park                                                       20
# Toronto Dominion Centre, Design Exchange                               30
# University of Toronto, Harbord                                         30
# Victoria Village                                                        5
# West Deane Park, Princess Gardens, Martin Grove...                      2
# Westmount                                                               8
# Weston                                                                  1
# Wexford, Maryvale                                                       5
# Willowdale South                                                       30
# Willowdale West                                                         6
# Willowdale, Newtonbrook                                                 2
# Woburn                                                                  4
# Woodbine Heights                                                        8
# York Mills West                                                         2
# York Mills, Silver Hills                                                1
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Agincourt                                                                5
# Alderwood, Long Branch                                                   7
# Bathurst Manor, Wilson Heights, Downsview North                         22
# Bayview Village                                                          4
# Bedford Park, Lawrence Manor East                                       25
# Berczy Park                                                             30
# Birch Cliff, Cliffside West                                              4
# Brockton, Parkdale Village, Exhibition Place                            23
# CN Tower, King and Spadina, Railway Lands, Harb...                      14
# Caledonia-Fairbanks                                                      4
# Cedarbrae                                                                8
# Central Bay Street                                                      30
# Christie                                                                16
# Church and Wellesley                                                    30
# Clairville, Humberwood, Woodbine Downs, West Hu...                       5
# Clarks Corners, Tam O'Shanter, Sullivan                                 13
# Cliffside, Cliffcrest, Scarborough Village West                          3
# Commerce Court, Victoria Hotel                                          30
# Davisville                                                              30
# Davisville North                                                         7
# Del Ray, Mount Dennis, Keelsdale and Silverthorn                         4
# Don Mills North                                                          5
# Don Mills South                                                         21
# Dorset Park, Wexford Heights, Scarborough Town ...                       6
# Downsview Central                                                        2
# Downsview East                                                           2
# Downsview Northwest                                                      5
# Downsview West                                                           6
# Dufferin, Dovercourt Village                                            15
# Enclave of L4W                                                          13
# ...                                                                    ...
# Rouge Hill, Port Union, Highland Creek                                   2
# Runnymede, Swansea                                                      30
# Runnymede, The Junction North                                            5
# Scarborough Village                                                      2
# South Steeles, Silverstone, Humbergate, Jamesto...                      12
# St. James Town                                                          30
# St. James Town, Cabbagetown                                             30
# Steeles West, L'Amoreaux West                                           15
# Studio District                                                         30
# Summerhill West, Rathnelly, South Hill, Forest ...                      14
# The Annex, North Midtown, Yorkville                                     22
# The Beaches                                                              4
# The Danforth  East                                                       3
# The Danforth West, Riverdale                                            30
# The Kingsway, Montgomery Road, Old Mill North                            2
# Thorncliffe Park                                                        20
# Toronto Dominion Centre, Design Exchange                                30
# University of Toronto, Harbord                                          30
# Victoria Village                                                         5
# West Deane Park, Princess Gardens, Martin Grove...                       2
# Westmount                                                                8
# Weston                                                                   1
# Wexford, Maryvale                                                        5
# Willowdale South                                                        30
# Willowdale West                                                          6
# Willowdale, Newtonbrook                                                  2
# Woburn                                                                   4
# Woodbine Heights                                                         8
# York Mills West                                                          2
# York Mills, Silver Hills                                                 1
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Agincourt                                               5               5
# Alderwood, Long Branch                                  7               7
# Bathurst Manor, Wilson Heights, Downsview North        22              22
# Bayview Village                                         4               4
# Bedford Park, Lawrence Manor East                      25              25
# Berczy Park                                            30              30
# Birch Cliff, Cliffside West                             4               4
# Brockton, Parkdale Village, Exhibition Place           23              23
# CN Tower, King and Spadina, Railway Lands, Harb...     14              14
# Caledonia-Fairbanks                                     4               4
# Cedarbrae                                               8               8
# Central Bay Street                                     30              30
# Christie                                               16              16
# Church and Wellesley                                   30              30
# Clairville, Humberwood, Woodbine Downs, West Hu...      5               5
# Clarks Corners, Tam O'Shanter, Sullivan                13              13
# Cliffside, Cliffcrest, Scarborough Village West         3               3
# Commerce Court, Victoria Hotel                         30              30
# Davisville                                             30              30
# Davisville North                                        7               7
# Del Ray, Mount Dennis, Keelsdale and Silverthorn        4               4
# Don Mills North                                         5               5
# Don Mills South                                        21              21
# Dorset Park, Wexford Heights, Scarborough Town ...      6               6
# Downsview Central                                       2               2
# Downsview East                                          2               2
# Downsview Northwest                                     5               5
# Downsview West                                          6               6
# Dufferin, Dovercourt Village                           15              15
# Enclave of L4W                                         13              13
# ...                                                   ...             ...
# Rouge Hill, Port Union, Highland Creek                  2               2
# Runnymede, Swansea                                     30              30
# Runnymede, The Junction North                           5               5
# Scarborough Village                                     2               2
# South Steeles, Silverstone, Humbergate, Jamesto...     12              12
# St. James Town                                         30              30
# St. James Town, Cabbagetown                            30              30
# Steeles West, L'Amoreaux West                          15              15
# Studio District                                        30              30
# Summerhill West, Rathnelly, South Hill, Forest ...     14              14
# The Annex, North Midtown, Yorkville                    22              22
# The Beaches                                             4               4
# The Danforth  East                                      3               3
# The Danforth West, Riverdale                           30              30
# The Kingsway, Montgomery Road, Old Mill North           2               2
# Thorncliffe Park                                       20              20
# Toronto Dominion Centre, Design Exchange               30              30
# University of Toronto, Harbord                         30              30
# Victoria Village                                        5               5
# West Deane Park, Princess Gardens, Martin Grove...      2               2
# Westmount                                               8               8
# Weston                                                  1               1
# Wexford, Maryvale                                       5               5
# Willowdale South                                       30              30
# Willowdale West                                         6               6
# Willowdale, Newtonbrook                                 2               2
# Woburn                                                  4               4
# Woodbine Heights                                        8               8
# York Mills West                                         2               2
# York Mills, Silver Hills                                1               1
#
#                                                     Venue Longitude  \
# Neighborhood
# Agincourt                                                         5
# Alderwood, Long Branch                                            7
# Bathurst Manor, Wilson Heights, Downsview North                  22
# Bayview Village                                                   4
# Bedford Park, Lawrence Manor East                                25
# Berczy Park                                                      30
# Birch Cliff, Cliffside West                                       4
# Brockton, Parkdale Village, Exhibition Place                     23
# CN Tower, King and Spadina, Railway Lands, Harb...               14
# Caledonia-Fairbanks                                               4
# Cedarbrae                                                         8
# Central Bay Street                                               30
# Christie                                                         16
# Church and Wellesley                                             30
# Clairville, Humberwood, Woodbine Downs, West Hu...                5
# Clarks Corners, Tam O'Shanter, Sullivan                          13
# Cliffside, Cliffcrest, Scarborough Village West                   3
# Commerce Court, Victoria Hotel                                   30
# Davisville                                                       30
# Davisville North                                                  7
# Del Ray, Mount Dennis, Keelsdale and Silverthorn                  4
# Don Mills North                                                   5
# Don Mills South                                                  21
# Dorset Park, Wexford Heights, Scarborough Town ...                6
# Downsview Central                                                 2
# Downsview East                                                    2
# Downsview Northwest                                               5
# Downsview West                                                    6
# Dufferin, Dovercourt Village                                     15
# Enclave of L4W                                                   13
# ...                                                             ...
# Rouge Hill, Port Union, Highland Creek                            2
# Runnymede, Swansea                                               30
# Runnymede, The Junction North                                     5
# Scarborough Village                                               2
# South Steeles, Silverstone, Humbergate, Jamesto...               12
# St. James Town                                                   30
# St. James Town, Cabbagetown                                      30
# Steeles West, L'Amoreaux West                                    15
# Studio District                                                  30
# Summerhill West, Rathnelly, South Hill, Forest ...               14
# The Annex, North Midtown, Yorkville                              22
# The Beaches                                                       4
# The Danforth  East                                                3
# The Danforth West, Riverdale                                     30
# The Kingsway, Montgomery Road, Old Mill North                     2
# Thorncliffe Park                                                 20
# Toronto Dominion Centre, Design Exchange                         30
# University of Toronto, Harbord                                   30
# Victoria Village                                                  5
# West Deane Park, Princess Gardens, Martin Grove...                2
# Westmount                                                         8
# Weston                                                            1
# Wexford, Maryvale                                                 5
# Willowdale South                                                 30
# Willowdale West                                                   6
# Willowdale, Newtonbrook                                           2
# Woburn                                                            4
# Woodbine Heights                                                  8
# York Mills West                                                   2
# York Mills, Silver Hills                                          1
#
#                                                     Venue Category
# Neighborhood
# Agincourt                                                        5
# Alderwood, Long Branch                                           7
# Bathurst Manor, Wilson Heights, Downsview North                 22
# Bayview Village                                                  4
# Bedford Park, Lawrence Manor East                               25
# Berczy Park                                                     30
# Birch Cliff, Cliffside West                                      4
# Brockton, Parkdale Village, Exhibition Place                    23
# CN Tower, King and Spadina, Railway Lands, Harb...              14
# Caledonia-Fairbanks                                              4
# Cedarbrae                                                        8
# Central Bay Street                                              30
# Christie                                                        16
# Church and Wellesley                                            30
# Clairville, Humberwood, Woodbine Downs, West Hu...               5
# Clarks Corners, Tam O'Shanter, Sullivan                         13
# Cliffside, Cliffcrest, Scarborough Village West                  3
# Commerce Court, Victoria Hotel                                  30
# Davisville                                                      30
# Davisville North                                                 7
# Del Ray, Mount Dennis, Keelsdale and Silverthorn                 4
# Don Mills North                                                  5
# Don Mills South                                                 21
# Dorset Park, Wexford Heights, Scarborough Town ...               6
# Downsview Central                                                2
# Downsview East                                                   2
# Downsview Northwest                                              5
# Downsview West                                                   6
# Dufferin, Dovercourt Village                                    15
# Enclave of L4W                                                  13
# ...                                                            ...
# Rouge Hill, Port Union, Highland Creek                           2
# Runnymede, Swansea                                              30
# Runnymede, The Junction North                                    5
# Scarborough Village                                              2
# South Steeles, Silverstone, Humbergate, Jamesto...              12
# St. James Town                                                  30
# St. James Town, Cabbagetown                                     30
# Steeles West, L'Amoreaux West                                   15
# Studio District                                                 30
# Summerhill West, Rathnelly, South Hill, Forest ...              14
# The Annex, North Midtown, Yorkville                             22
# The Beaches                                                      4
# The Danforth  East                                               3
# The Danforth West, Riverdale                                    30
# The Kingsway, Montgomery Road, Old Mill North                    2
# Thorncliffe Park                                                20
# Toronto Dominion Centre, Design Exchange                        30
# University of Toronto, Harbord                                  30
# Victoria Village                                                 5
# West Deane Park, Princess Gardens, Martin Grove...               2
# Westmount                                                        8
# Weston                                                           1
# Wexford, Maryvale                                                5
# Willowdale South                                                30
# Willowdale West                                                  6
# Willowdale, Newtonbrook                                          2
# Woburn                                                           4
# Woodbine Heights                                                 8
# York Mills West                                                  2
# York Mills, Silver Hills                                         1
#
# [101 rows x 6 columns]

# %% [markdown]
# <h4>Determine the number of unique categories can be curated from all the returned venues

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 237 uniques categories.

# %% [markdown]
# <h4>Analyze each neighborhood individually

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

# %% [markdown]
# <h4>Examine the new dataframe size.

# %%
toronto_onehot.shape
# Out:
# (1337, 237)

# %% [markdown]
# <h4>Next, group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

# %% [markdown]
# <h4>Print each neighborhood along with the top 5 most common venues

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Agincourt----
#                        venue  freq
# 0             Breakfast Spot   0.2
# 1                     Lounge   0.2
# 2             Clothing Store   0.2
# 3  Latin American Restaurant   0.2
# 4               Skating Rink   0.2
#
#
# ----Alderwood, Long Branch----
#             venue  freq
# 0     Pizza Place  0.29
# 1  Sandwich Place  0.14
# 2             Gym  0.14
# 3             Pub  0.14
# 4     Coffee Shop  0.14
#
#
# ----Bathurst Manor, Wilson Heights, Downsview North----
#                        venue  freq
# 0                       Bank  0.09
# 1                Coffee Shop  0.09
# 2                Pizza Place  0.05
# 3                      Diner  0.05
# 4  Middle Eastern Restaurant  0.05
#
#
# ----Bayview Village----
#                  venue  freq
# 0                 Bank  0.25
# 1   Chinese Restaurant  0.25
# 2  Japanese Restaurant  0.25
# 3                 Café  0.25
# 4          Yoga Studio  0.00
#
#
# ----Bedford Park, Lawrence Manor East----
#                   venue  freq
# 0    Italian Restaurant  0.08
# 1        Sandwich Place  0.08
# 2           Coffee Shop  0.08
# 3                   Pub  0.04
# 4  Fast Food Restaurant  0.04
#
#
# ----Berczy Park----
#                 venue  freq
# 0      Farmers Market  0.07
# 1            Beer Bar  0.07
# 2         Coffee Shop  0.07
# 3        Cocktail Bar  0.07
# 4  Seafood Restaurant  0.07
#
#
# ----Birch Cliff, Cliffside West----
#                    venue  freq
# 0        College Stadium  0.25
# 1           Skating Rink  0.25
# 2  General Entertainment  0.25
# 3                   Café  0.25
# 4                 Museum  0.00
#
#
# ----Brockton, Parkdale Village, Exhibition Place----
#             venue  freq
# 0            Café  0.13
# 1  Breakfast Spot  0.09
# 2          Bakery  0.09
# 3     Coffee Shop  0.09
# 4       Nightclub  0.04
#
#
# ----CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport----
#               venue  freq
# 0    Airport Lounge  0.14
# 1          Boutique  0.07
# 2  Airport Terminal  0.07
# 3     Boat or Ferry  0.07
# 4               Bar  0.07
#
#
# ----Caledonia-Fairbanks----
#               venue  freq
# 0              Park  0.50
# 1     Women's Store  0.25
# 2              Pool  0.25
# 3         Wine Shop  0.00
# 4  Malay Restaurant  0.00
#
#
# ----Cedarbrae----
#                  venue  freq
# 0     Hakka Restaurant  0.12
# 1   Athletics & Sports  0.12
# 2  Fried Chicken Joint  0.12
# 3                 Bank  0.12
# 4               Bakery  0.12
#
#
# ----Central Bay Street----
#                  venue  freq
# 0          Coffee Shop  0.23
# 1                 Café  0.07
# 2   Italian Restaurant  0.07
# 3          Yoga Studio  0.03
# 4  Japanese Restaurant  0.03
#
#
# ----Christie----
#            venue  freq
# 0  Grocery Store  0.25
# 1           Café  0.19
# 2           Park  0.12
# 3      Nightclub  0.06
# 4    Coffee Shop  0.06
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0             Creperie  0.03
# 1       Breakfast Spot  0.03
# 2  Martial Arts School  0.03
# 3          Escape Room  0.03
# 4      Bubble Tea Shop  0.03
#
#
# ----Clairville, Humberwood, Woodbine Downs, West Humber, Kipling Heights, Rexdale, Elms, Tandridge, Old Rexdale----
#                  venue  freq
# 0            Drugstore   0.2
# 1        Garden Center   0.2
# 2                  Bar   0.2
# 3           Truck Stop   0.2
# 4  Rental Car Location   0.2
#
#
# ----Clarks Corners, Tam O'Shanter, Sullivan----
#                   venue  freq
# 0           Pizza Place  0.15
# 1  Fast Food Restaurant  0.15
# 2          Noodle House  0.08
# 3    Chinese Restaurant  0.08
# 4   Fried Chicken Joint  0.08
#
#
# ----Cliffside, Cliffcrest, Scarborough Village West----
#                  venue  freq
# 0  American Restaurant  0.33
# 1                Motel  0.33
# 2         Intersection  0.33
# 3          Yoga Studio  0.00
# 4               Museum  0.00
#
#
# ----Commerce Court, Victoria Hotel----
#                  venue  freq
# 0                 Café  0.13
# 1  Japanese Restaurant  0.07
# 2                Hotel  0.07
# 3          Coffee Shop  0.07
# 4  American Restaurant  0.07
#
#
# ----Davisville----
#             venue  freq
# 0    Dessert Shop  0.10
# 1     Pizza Place  0.07
# 2            Café  0.07
# 3  Sandwich Place  0.07
# 4             Gym  0.07
#
#
# ----Davisville North----
#                venue  freq
# 0   Department Store  0.14
# 1              Hotel  0.14
# 2     Sandwich Place  0.14
# 3  Food & Drink Shop  0.14
# 4               Park  0.14
#
#
# ----Del Ray, Mount Dennis, Keelsdale and Silverthorn----
#                 venue  freq
# 0        Skating Rink  0.25
# 1  Turkish Restaurant  0.25
# 2      Discount Store  0.25
# 3      Sandwich Place  0.25
# 4         Yoga Studio  0.00
#
#
# ----Don Mills North----
#                   venue  freq
# 0   Japanese Restaurant   0.2
# 1          Dessert Shop   0.2
# 2                   Gym   0.2
# 3                  Café   0.2
# 4  Caribbean Restaurant   0.2
#
#
# ----Don Mills South----
#                 venue  freq
# 0          Restaurant  0.10
# 1                 Gym  0.10
# 2         Coffee Shop  0.10
# 3  Italian Restaurant  0.05
# 4  Chinese Restaurant  0.05
#
#
# ----Dorset Park, Wexford Heights, Scarborough Town Centre----
#                    venue  freq
# 0      Indian Restaurant  0.33
# 1                Brewery  0.17
# 2     Chinese Restaurant  0.17
# 3  Vietnamese Restaurant  0.17
# 4              Pet Store  0.17
#
#
# ----Downsview Central----
#             venue  freq
# 0  Baseball Field   0.5
# 1      Food Truck   0.5
# 2     Yoga Studio   0.0
# 3           Motel   0.0
# 4  Massage Studio   0.0
#
#
# ----Downsview East----
#             venue  freq
# 0         Airport   0.5
# 1            Park   0.5
# 2     Yoga Studio   0.0
# 3   Movie Theater   0.0
# 4  Massage Studio   0.0
#
#
# ----Downsview Northwest----
#                   venue  freq
# 0    Athletics & Sports   0.2
# 1  Gym / Fitness Center   0.2
# 2        Discount Store   0.2
# 3         Grocery Store   0.2
# 4          Liquor Store   0.2
#
#
# ----Downsview West----
#            venue  freq
# 0  Grocery Store  0.33
# 1           Park  0.17
# 2          Hotel  0.17
# 3  Shopping Mall  0.17
# 4           Bank  0.17
#
#
# ----Dufferin, Dovercourt Village----
#          venue  freq
# 0       Bakery  0.13
# 1     Pharmacy  0.13
# 2         Bank  0.07
# 3  Music Venue  0.07
# 4    Wine Shop  0.07
#
#
# ----Enclave of L4W----
#                       venue  freq
# 0               Coffee Shop  0.23
# 1                     Hotel  0.15
# 2            Sandwich Place  0.08
# 3  Mediterranean Restaurant  0.08
# 4              Intersection  0.08
#
#
# ----Enclave of M4L----
#                   venue  freq
# 0           Yoga Studio  0.06
# 1            Restaurant  0.06
# 2  Fast Food Restaurant  0.06
# 3        Farmers Market  0.06
# 4         Burrito Place  0.06
#
#
# ----Enclave of M5E----
#                 venue  freq
# 0      Farmers Market  0.07
# 1                Café  0.07
# 2            Creperie  0.07
# 3  Seafood Restaurant  0.07
# 4            Beer Bar  0.07
#
#
# ----Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood----
#                venue  freq
# 0               Café  0.11
# 1       Liquor Store  0.11
# 2     Shopping Plaza  0.11
# 3  Convenience Store  0.11
# 4        Pizza Place  0.11
#
#
# ----Fairview, Henry Farm, Oriole----
#             venue  freq
# 0     Coffee Shop  0.17
# 1  Clothing Store  0.10
# 2            Bank  0.07
# 3      Restaurant  0.07
# 4       Juice Bar  0.07
#
#
# ----First Canadian Place, Underground city----
#                 venue  freq
# 0                Café  0.17
# 1         Coffee Shop  0.10
# 2          Restaurant  0.10
# 3               Hotel  0.07
# 4  Seafood Restaurant  0.07
#
#
# ----Forest Hill North & West----
#               venue  freq
# 0  Sushi Restaurant  0.25
# 1          Bus Line  0.25
# 2             Trail  0.25
# 3     Jewelry Store  0.25
# 4       Yoga Studio  0.00
#
#
# ----Garden District, Ryerson----
#                venue  freq
# 0               Café  0.10
# 1     Clothing Store  0.07
# 2   Ramen Restaurant  0.07
# 3              Plaza  0.03
# 4  Electronics Store  0.03
#
#
# ----Glencairn----
#                  venue  freq
# 0  Japanese Restaurant  0.25
# 1           Playground  0.25
# 2                 Park  0.25
# 3               Bakery  0.25
# 4        Movie Theater  0.00
#
#
# ----Golden Mile, Clairlea, Oakridge----
#            venue  freq
# 0       Bus Line   0.2
# 1         Bakery   0.2
# 2           Park   0.1
# 3  Metro Station   0.1
# 4   Soccer Field   0.1
#
#
# ----Guildwood, Morningside, West Hill----
#                 venue  freq
# 0        Intersection  0.11
# 1      Breakfast Spot  0.11
# 2      Medical Center  0.11
# 3  Mexican Restaurant  0.11
# 4   Electronics Store  0.11
#
#
# ----Harbourfront East, Union Station, Toronto Islands----
#                      venue  freq
# 0                    Plaza  0.07
# 1                    Hotel  0.07
# 2                     Park  0.07
# 3                     Café  0.07
# 4  New American Restaurant  0.03
#
#
# ----High Park, The Junction South----
#                  venue  freq
# 0   Mexican Restaurant  0.08
# 1                 Café  0.08
# 2      Thai Restaurant  0.08
# 3  Arts & Crafts Store  0.08
# 4               Bakery  0.04
#
#
# ----Hillcrest Village----
#                       venue  freq
# 0                      Pool   0.2
# 1  Mediterranean Restaurant   0.2
# 2               Golf Course   0.2
# 3                   Dog Run   0.2
# 4      Fast Food Restaurant   0.2
#
#
# ----Humber Summit----
#            venue  freq
# 0            Gym  0.33
# 1    Pizza Place  0.33
# 2   Home Service  0.33
# 3    Yoga Studio  0.00
# 4  Movie Theater  0.00
#
#
# ----Humberlea, Emery----
#             venue  freq
# 0  Baseball Field   1.0
# 1     Yoga Studio   0.0
# 2          Market   0.0
# 3  Massage Studio   0.0
# 4  Medical Center   0.0
#
#
# ----Humewood-Cedarvale----
#           venue  freq
# 0         Field  0.25
# 1  Hockey Arena  0.25
# 2          Park  0.25
# 3         Trail  0.25
# 4         Motel  0.00
#
#
# ----India Bazaar, The Beaches West----
#             venue  freq
# 0     Pizza Place  0.10
# 1            Park  0.10
# 2  Sandwich Place  0.10
# 3    Liquor Store  0.05
# 4       Pet Store  0.05
#
#
# ----Kennedy Park, Ionview, East Birchmount Park----
#                venue  freq
# 0  Convenience Store  0.25
# 1         Hobby Shop  0.25
# 2        Coffee Shop  0.25
# 3   Department Store  0.25
# 4      Metro Station  0.00
#
#
# ----Kensington Market, Chinatown, Grange Park----
#                    venue  freq
# 0                   Café  0.10
# 1  Vietnamese Restaurant  0.07
# 2   Caribbean Restaurant  0.07
# 3                 Bakery  0.07
# 4            Fish Market  0.03
#
#
# ----Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens----
#                venue  freq
# 0               Park  0.33
# 1  Mobile Phone Shop  0.33
# 2     Sandwich Place  0.33
# 3        Yoga Studio  0.00
# 4              Motel  0.00
#
#
# ----Lawrence Manor, Lawrence Heights----
#                    venue  freq
# 0         Clothing Store  0.25
# 1            Coffee Shop  0.12
# 2            Event Space  0.12
# 3               Boutique  0.12
# 4  Vietnamese Restaurant  0.12
#
#
# ----Lawrence Park----
#                 venue  freq
# 0  Dim Sum Restaurant  0.25
# 1         Swim School  0.25
# 2                Park  0.25
# 3            Bus Line  0.25
# 4               Motel  0.00
#
#
# ----Leaside----
#                  venue  freq
# 0  Sporting Goods Shop  0.10
# 1          Coffee Shop  0.10
# 2         Burger Joint  0.07
# 3                 Bank  0.07
# 4     Sushi Restaurant  0.07
#
#
# ----Little Portugal, Trinity----
#                    venue  freq
# 0                    Bar  0.10
# 1       Asian Restaurant  0.07
# 2  Vietnamese Restaurant  0.07
# 3            Men's Store  0.03
# 4      Korean Restaurant  0.03
#
#
# ----Malvern, Rouge----
#                       venue  freq
# 0      Fast Food Restaurant   1.0
# 1             Movie Theater   0.0
# 2            Massage Studio   0.0
# 3            Medical Center   0.0
# 4  Mediterranean Restaurant   0.0
#
#
# ----Milliken, Agincourt North, Steeles East, L'Amoreaux East----
#           venue  freq
# 0    Playground  0.33
# 1          Park  0.33
# 2  Intersection  0.33
# 3   Yoga Studio  0.00
# 4         Motel  0.00
#
#
# ----Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West----
#                venue  freq
# 0  Convenience Store  0.08
# 1      Grocery Store  0.08
# 2       Burger Joint  0.08
# 3      Burrito Place  0.08
# 4    Supplement Shop  0.08
#
#
# ----Moore Park, Summerhill East----
#                  venue  freq
# 0               Lawyer  0.33
# 1                 Park  0.33
# 2         Tennis Court  0.33
# 3          Yoga Studio  0.00
# 4  Monument / Landmark  0.00
#
#
# ----New Toronto, Mimico South, Humber Bay Shores----
#                   venue  freq
# 0                  Café  0.17
# 1  Fast Food Restaurant  0.08
# 2              Pharmacy  0.08
# 3          Liquor Store  0.08
# 4           Flower Shop  0.08
#
#
# ----North Park, Maple Leaf Park, Upwood Park----
#                         venue  freq
# 0                        Park   0.2
# 1                      Bakery   0.2
# 2  Construction & Landscaping   0.2
# 3                       Trail   0.2
# 4            Basketball Court   0.2
#
#
# ----North Toronto West----
#             venue  freq
# 0  Clothing Store  0.14
# 1     Coffee Shop  0.09
# 2     Yoga Studio  0.05
# 3             Spa  0.05
# 4       Pet Store  0.05
#
#
# ----Northwood Park, York University----
#                    venue  freq
# 0         Massage Studio  0.14
# 1  Vietnamese Restaurant  0.14
# 2   Caribbean Restaurant  0.14
# 3                    Bar  0.14
# 4            Coffee Shop  0.14
#
#
# ----Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East----
#             venue  freq
# 0  Baseball Field   1.0
# 1     Yoga Studio   0.0
# 2          Market   0.0
# 3  Massage Studio   0.0
# 4  Medical Center   0.0
#
#
# ----Ontario Provincial Government----
#                venue  freq
# 0        Coffee Shop  0.20
# 1   Sushi Restaurant  0.07
# 2        Yoga Studio  0.03
# 3  College Cafeteria  0.03
# 4                Spa  0.03
#
#
# ----Parkdale, Roncesvalles----
#             venue  freq
# 0  Breakfast Spot  0.14
# 1       Gift Shop  0.14
# 2       Bookstore  0.07
# 3     Coffee Shop  0.07
# 4             Bar  0.07
#
#
# ----Parkview Hill, Woodbine Gardens----
#                   venue  freq
# 0           Pizza Place  0.18
# 1                  Café  0.09
# 2        Breakfast Spot  0.09
# 3  Gym / Fitness Center  0.09
# 4              Pharmacy  0.09
#
#
# ----Parkwoods----
#                   venue  freq
# 0  Fast Food Restaurant  0.25
# 1     Food & Drink Shop  0.25
# 2                  Park  0.25
# 3              Bus Stop  0.25
# 4                 Motel  0.00
#
#
# ----Regent Park, Harbourfront----
#             venue  freq
# 0     Coffee Shop  0.20
# 1            Park  0.10
# 2          Bakery  0.10
# 3  Breakfast Spot  0.07
# 4             Pub  0.03
#
#
# ----Richmond, Adelaide, King----
#                  venue  freq
# 0          Coffee Shop  0.10
# 1                 Café  0.10
# 2  American Restaurant  0.07
# 3           Smoke Shop  0.03
# 4      Thai Restaurant  0.03
#
#
# ----Rosedale----
#                  venue  freq
# 0                 Park  0.50
# 1           Playground  0.25
# 2                Trail  0.25
# 3          Yoga Studio  0.00
# 4  Monument / Landmark  0.00
#
#
# ----Roselawn----
#             venue  freq
# 0    Home Service   0.5
# 1          Garden   0.5
# 2     Yoga Studio   0.0
# 3          Museum   0.0
# 4  Medical Center   0.0
#
#
# ----Rouge Hill, Port Union, Highland Creek----
#                         venue  freq
# 0  Construction & Landscaping   0.5
# 1                         Bar   0.5
# 2                 Yoga Studio   0.0
# 3               Movie Theater   0.0
# 4              Medical Center   0.0
#
#
# ----Runnymede, Swansea----
#                 venue  freq
# 0                Café  0.10
# 1         Pizza Place  0.07
# 2    Sushi Restaurant  0.07
# 3  Italian Restaurant  0.07
# 4         Coffee Shop  0.07
#
#
# ----Runnymede, The Junction North----
#                venue  freq
# 0        Pizza Place   0.2
# 1      Grocery Store   0.2
# 2  Convenience Store   0.2
# 3            Brewery   0.2
# 4           Bus Line   0.2
#
#
# ----Scarborough Village----
#             venue  freq
# 0      Playground   0.5
# 1             Spa   0.5
# 2     Yoga Studio   0.0
# 3           Motel   0.0
# 4  Massage Studio   0.0
#
#
# ----South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens----
#             venue  freq
# 0   Grocery Store  0.17
# 1  Sandwich Place  0.08
# 2     Coffee Shop  0.08
# 3      Beer Store  0.08
# 4    Liquor Store  0.08
#
#
# ----St. James Town----
#                  venue  freq
# 0                 Café  0.10
# 1       Farmers Market  0.07
# 2  Japanese Restaurant  0.07
# 3            Gastropub  0.07
# 4          Coffee Shop  0.07
#
#
# ----St. James Town, Cabbagetown----
#                 venue  freq
# 0              Bakery  0.07
# 1                Café  0.07
# 2  Italian Restaurant  0.07
# 3          Restaurant  0.07
# 4           Gastropub  0.03
#
#
# ----Steeles West, L'Amoreaux West----
#                   venue  freq
# 0  Fast Food Restaurant  0.13
# 1           Coffee Shop  0.13
# 2          Burger Joint  0.07
# 3                  Bank  0.07
# 4          Camera Store  0.07
#
#
# ----Studio District----
#                  venue  freq
# 0          Coffee Shop  0.10
# 1               Bakery  0.07
# 2                 Café  0.07
# 3  American Restaurant  0.07
# 4          Yoga Studio  0.03
#
#
# ----Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park----
#                  venue  freq
# 0          Coffee Shop  0.14
# 1   Light Rail Station  0.14
# 2          Supermarket  0.07
# 3  Fried Chicken Joint  0.07
# 4     Sushi Restaurant  0.07
#
#
# ----The Annex, North Midtown, Yorkville----
#             venue  freq
# 0            Café  0.14
# 1  Sandwich Place  0.14
# 2     Coffee Shop  0.09
# 3             Pub  0.05
# 4     Pizza Place  0.05
#
#
# ----The Beaches----
#                        venue  freq
# 0          Health Food Store  0.25
# 1                        Pub  0.25
# 2                      Trail  0.25
# 3                Yoga Studio  0.00
# 4  Middle Eastern Restaurant  0.00
#
#
# ----The Danforth  East----
#                venue  freq
# 0        Coffee Shop  0.33
# 1  Convenience Store  0.33
# 2               Park  0.33
# 3        Yoga Studio  0.00
# 4      Movie Theater  0.00
#
#
# ----The Danforth West, Riverdale----
#                 venue  freq
# 0    Greek Restaurant  0.20
# 1      Ice Cream Shop  0.07
# 2         Coffee Shop  0.07
# 3  Italian Restaurant  0.07
# 4         Yoga Studio  0.03
#
#
# ----The Kingsway, Montgomery Road, Old Mill North----
#             venue  freq
# 0            Pool   0.5
# 1           River   0.5
# 2   Movie Theater   0.0
# 3  Massage Studio   0.0
# 4  Medical Center   0.0
#
#
# ----Thorncliffe Park----
#                        venue  freq
# 0          Indian Restaurant  0.10
# 1             Sandwich Place  0.10
# 2                Yoga Studio  0.05
# 3               Burger Joint  0.05
# 4  Middle Eastern Restaurant  0.05
#
#
# ----Toronto Dominion Centre, Design Exchange----
#                  venue  freq
# 0                 Café  0.13
# 1          Coffee Shop  0.10
# 2           Restaurant  0.10
# 3               Bakery  0.07
# 4  Japanese Restaurant  0.07
#
#
# ----University of Toronto, Harbord----
#                  venue  freq
# 0                 Café  0.17
# 1       Sandwich Place  0.07
# 2                  Bar  0.07
# 3  Japanese Restaurant  0.07
# 4            Bookstore  0.07
#
#
# ----Victoria Village----
#                    venue  freq
# 0  Portuguese Restaurant   0.2
# 1      French Restaurant   0.2
# 2           Intersection   0.2
# 3            Coffee Shop   0.2
# 4           Hockey Arena   0.2
#
#
# ----West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale----
#                        venue  freq
# 0  Middle Eastern Restaurant   0.5
# 1                     Bakery   0.5
# 2                Yoga Studio   0.0
# 3                     Market   0.0
# 4             Massage Studio   0.0
#
#
# ----Westmount----
#                 venue  freq
# 0      Sandwich Place  0.12
# 1  Chinese Restaurant  0.12
# 2          Playground  0.12
# 3         Pizza Place  0.12
# 4      Discount Store  0.12
#
#
# ----Weston----
#                       venue  freq
# 0         Convenience Store   1.0
# 1               Yoga Studio   0.0
# 2                    Museum   0.0
# 3            Medical Center   0.0
# 4  Mediterranean Restaurant   0.0
#
#
# ----Wexford, Maryvale----
#                        venue  freq
# 0                Auto Garage   0.2
# 1  Middle Eastern Restaurant   0.2
# 2                     Bakery   0.2
# 3             Sandwich Place   0.2
# 4      Vietnamese Restaurant   0.2
#
#
# ----Willowdale South----
#               venue  freq
# 0  Ramen Restaurant  0.10
# 1       Pizza Place  0.07
# 2              Café  0.07
# 3       Coffee Shop  0.07
# 4         Juice Bar  0.03
#
#
# ----Willowdale West----
#             venue  freq
# 0         Butcher  0.17
# 1  Discount Store  0.17
# 2     Pizza Place  0.17
# 3        Pharmacy  0.17
# 4     Coffee Shop  0.17
#
#
# ----Willowdale, Newtonbrook----
#             venue  freq
# 0            Park   1.0
# 1     Yoga Studio   0.0
# 2   Movie Theater   0.0
# 3  Massage Studio   0.0
# 4  Medical Center   0.0
#
#
# ----Woburn----
#                    venue  freq
# 0            Coffee Shop  0.50
# 1           Soccer Field  0.25
# 2  Korean BBQ Restaurant  0.25
# 3            Yoga Studio  0.00
# 4          Movie Theater  0.00
#
#
# ----Woodbine Heights----
#           venue  freq
# 0  Skating Rink  0.25
# 1      Bus Stop  0.12
# 2    Beer Store  0.12
# 3  Intersection  0.12
# 4   Video Store  0.12
#
#
# ----York Mills West----
#                venue  freq
# 0  Convenience Store   0.5
# 1               Park   0.5
# 2        Yoga Studio   0.0
# 3      Movie Theater   0.0
# 4     Medical Center   0.0
#
#
# ----York Mills, Silver Hills----
#             venue  freq
# 0            Park   1.0
# 1     Yoga Studio   0.0
# 2   Movie Theater   0.0
# 3  Massage Studio   0.0
# 4  Medical Center   0.0

# %% [markdown]
# <h4>Upload new results into a pandas dataframe

# %% [markdown]
# <h4>A function to sort the venues in descending order.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# <h4>Create the new dataframe and display the top 10 venues for each neighborhood.

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                       Neighborhood 1st Most Common Venue  \
# 0                                        Agincourt                Lounge
# 1                           Alderwood, Long Branch           Pizza Place
# 2  Bathurst Manor, Wilson Heights, Downsview North                  Bank
# 3                                  Bayview Village                  Café
# 4                Bedford Park, Lawrence Manor East        Sandwich Place
#
#   2nd Most Common Venue 3rd Most Common Venue      4th Most Common Venue  \
# 0        Breakfast Spot        Clothing Store  Latin American Restaurant
# 1                   Gym                   Pub               Skating Rink
# 2           Coffee Shop           Pizza Place              Deli / Bodega
# 3    Chinese Restaurant                  Bank        Japanese Restaurant
# 4           Coffee Shop    Italian Restaurant                   Pharmacy
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0          Skating Rink      Department Store     Electronics Store
# 1        Sandwich Place           Coffee Shop               Dog Run
# 2      Sushi Restaurant           Supermarket           Bridal Shop
# 3      Department Store           Escape Room     Electronics Store
# 4                   Pub             Juice Bar               Butcher
#
#          8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0  Eastern European Restaurant             Drugstore             Donut Shop
# 1                   Donut Shop   Distribution Center           Dance Studio
# 2                        Diner         Shopping Mall         Sandwich Place
# 3  Eastern European Restaurant             Drugstore             Donut Shop
# 4         Fast Food Restaurant                  Café      Indian Restaurant

# %% [markdown]
# <h4>Run <i>k-means</i> to cluster the neighborhood into 9 clusters.

# %%
# set number of clusters
kclusters = 9

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([6, 3, 6, 6, 6, 6, 6, 6, 6, 0])

# %% [markdown]
# <h4>Create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = main_df

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head() # check the last columns!
# Out:
#             Borough                      Neighborhood PostalCode   Latitude  \
# 0        North York                         Parkwoods        M3A  43.753259
# 1        North York                  Victoria Village        M4A  43.725882
# 2  Downtown Toronto         Regent Park, Harbourfront        M5A  43.654260
# 3        North York  Lawrence Manor, Lawrence Heights        M6A  43.718518
# 4      Queen's Park     Ontario Provincial Government        M7A  43.662301
#
#    Longitude  Cluster Labels 1st Most Common Venue   2nd Most Common Venue  \
# 0 -79.329656             0.0              Bus Stop    Fast Food Restaurant
# 1 -79.315572             6.0          Intersection   Portuguese Restaurant
# 2 -79.360636             6.0           Coffee Shop                  Bakery
# 3 -79.464763             6.0        Clothing Store  Furniture / Home Store
# 4 -79.389494             6.0           Coffee Shop        Sushi Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                  Park     Food & Drink Shop         Women's Store
# 1           Coffee Shop     French Restaurant          Hockey Arena
# 2                  Park        Breakfast Spot  Gym / Fitness Center
# 3     Accessories Store           Event Space              Boutique
# 4                   Gym            Hobby Shop                   Bar
#
#          6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0  Eastern European Restaurant             Drugstore            Donut Shop
# 1                        Diner         Deli / Bodega      Department Store
# 2                Historic Site            Restaurant                   Pub
# 3        Vietnamese Restaurant           Coffee Shop   Distribution Center
# 4                     Beer Bar                   Spa         Smoothie Shop
#
#    9th Most Common Venue 10th Most Common Venue
# 0                Dog Run    Distribution Center
# 1           Dessert Shop     Dim Sum Restaurant
# 2  Performing Arts Venue     Mexican Restaurant
# 3     Dim Sum Restaurant                  Diner
# 4          Burrito Place         Sandwich Place

# %% [markdown]
# <h4>Import plotting libraries

# %%
#Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# %% [markdown]
# <h4>Finally visualize the resulting clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[1],
        fill=True,
        fill_color=rainbow[1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_275eb99c97f94cf4a3a980ddbf490616%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_275eb99c97f94cf4a3a980ddbf490616%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_275eb99c97f94cf4a3a980ddbf490616%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_275eb99c97f94cf4a3a980ddbf490616%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.6542599%2C-79.3606359%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# <h4>Examine the clusters obtained individually

# %% [markdown]
# <h4>Cluster 1

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                    Neighborhood  Cluster Labels 1st Most Common Venue  \
# 0                     Parkwoods             0.0              Bus Stop
# 16           Humewood-Cedarvale             0.0                 Field
# 21          Caledonia-Fairbanks             0.0                  Park
# 35           The Danforth  East             0.0           Coffee Shop
# 40               Downsview East             0.0               Airport
# 61                Lawrence Park             0.0                  Park
# 66              York Mills West             0.0                  Park
# 83  Moore Park, Summerhill East             0.0                Lawyer
# 91                     Rosedale             0.0                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0   Fast Food Restaurant                  Park     Food & Drink Shop
# 16                  Park                 Trail          Hockey Arena
# 21         Women's Store                  Pool          Dance Studio
# 35                  Park     Convenience Store         Women's Store
# 40                  Park         Women's Store         Deli / Bodega
# 61           Swim School    Dim Sum Restaurant              Bus Line
# 66     Convenience Store         Women's Store         Deli / Bodega
# 83                  Park          Tennis Court         Women's Store
# 91            Playground                 Trail           Curling Ice
#
#           5th Most Common Venue        6th Most Common Venue  \
# 0                 Women's Store  Eastern European Restaurant
# 16                Women's Store               Discount Store
# 21            Electronics Store  Eastern European Restaurant
# 35                Deli / Bodega            Electronics Store
# 40                  Escape Room            Electronics Store
# 61                Women's Store             Department Store
# 66            Electronics Store  Eastern European Restaurant
# 83                Deli / Bodega            Electronics Store
# 91  Eastern European Restaurant                    Drugstore
#
#           7th Most Common Venue        8th Most Common Venue  \
# 0                     Drugstore                   Donut Shop
# 16             Department Store                 Dessert Shop
# 21                    Drugstore                   Donut Shop
# 35  Eastern European Restaurant                    Drugstore
# 40  Eastern European Restaurant                    Drugstore
# 61            Electronics Store  Eastern European Restaurant
# 66                    Drugstore                   Donut Shop
# 83  Eastern European Restaurant                    Drugstore
# 91                   Donut Shop                      Dog Run
#
#    9th Most Common Venue 10th Most Common Venue
# 0                Dog Run    Distribution Center
# 16    Dim Sum Restaurant                  Diner
# 21               Dog Run    Distribution Center
# 35            Donut Shop                Dog Run
# 40            Donut Shop                Dog Run
# 61             Drugstore             Donut Shop
# 66               Dog Run    Distribution Center
# 83            Donut Shop                Dog Run
# 91   Distribution Center         Discount Store

# %% [markdown]
# <h4> Cluster 2

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                                          Neighborhood  Cluster Labels  \
# 10                                          Glencairn             1.0
# 32                                Scarborough Village             1.0
# 85  Milliken, Agincourt North, Steeles East, L'Amo...             1.0
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 10            Playground                  Park                Bakery
# 32            Playground                   Spa     College Cafeteria
# 85            Playground          Intersection                  Park
#
#    4th Most Common Venue        5th Most Common Venue 6th Most Common Venue  \
# 10   Japanese Restaurant                Deli / Bodega     Electronics Store
# 32     Electronics Store  Eastern European Restaurant             Drugstore
# 85     Electronics Store  Eastern European Restaurant             Drugstore
#
#           7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 10  Eastern European Restaurant             Drugstore            Donut Shop
# 32                   Donut Shop               Dog Run   Distribution Center
# 85                   Donut Shop               Dog Run   Distribution Center
#
#    10th Most Common Venue
# 10                Dog Run
# 32         Discount Store
# 85         Discount Store

# %% [markdown]
# <h4> Cluster 3

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#      Neighborhood  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 50  Humber Summit             2.0                   Gym           Pizza Place
# 62       Roselawn             2.0          Home Service                Garden
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 50          Home Service          Dance Studio     Electronics Store
# 62         Women's Store          Dance Studio     Electronics Store
#
#           6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 50  Eastern European Restaurant             Drugstore            Donut Shop
# 62  Eastern European Restaurant             Drugstore            Donut Shop
#
#    9th Most Common Venue 10th Most Common Venue
# 50               Dog Run    Distribution Center
# 62               Dog Run    Distribution Center

# %% [markdown]
# <h4> Cluster 4

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                                           Neighborhood  Cluster Labels  \
# 25                                            Christie             3.0
# 29                                    Thorncliffe Park             3.0
# 46                                      Downsview West             3.0
# 47                      India Bazaar, The Beaches West             3.0
# 56    Del Ray, Mount Dennis, Keelsdale and Silverthorn             3.0
# 60                                 Downsview Northwest             3.0
# 63                       Runnymede, The Junction North             3.0
# 65   Dorset Park, Wexford Heights, Scarborough Town...             3.0
# 67                                    Davisville North             3.0
# 70                                           Westmount             3.0
# 71                                   Wexford, Maryvale             3.0
# 74                 The Annex, North Midtown, Yorkville             3.0
# 77   Kingsview Village, St. Phillips, Martin Grove ...             3.0
# 89   South Steeles, Silverstone, Humbergate, Jamest...             3.0
# 90                       Steeles West, L'Amoreaux West             3.0
# 93                              Alderwood, Long Branch             3.0
# 102  Mimico NW, The Queensway West, South of Bloor,...             3.0
#
#     1st Most Common Venue  2nd Most Common Venue 3rd Most Common Venue  \
# 25          Grocery Store                   Café                  Park
# 29      Indian Restaurant         Sandwich Place           Yoga Studio
# 46          Grocery Store          Shopping Mall                  Park
# 47            Pizza Place                   Park        Sandwich Place
# 56         Sandwich Place           Skating Rink        Discount Store
# 60   Gym / Fitness Center     Athletics & Sports          Liquor Store
# 63          Grocery Store            Pizza Place               Brewery
# 65      Indian Restaurant     Chinese Restaurant             Pet Store
# 67   Gym / Fitness Center                  Hotel        Breakfast Spot
# 70             Playground     Chinese Restaurant        Discount Store
# 71         Sandwich Place  Vietnamese Restaurant                Bakery
# 74         Sandwich Place                   Café           Coffee Shop
# 77                   Park      Mobile Phone Shop        Sandwich Place
# 89          Grocery Store    Fried Chicken Joint           Coffee Shop
# 90            Coffee Shop   Fast Food Restaurant                   Gym
# 93            Pizza Place                    Gym                   Pub
# 102         Grocery Store          Tanning Salon     Convenience Store
#
#          4th Most Common Venue 5th Most Common Venue  \
# 25          Athletics & Sports            Baby Store
# 29                        Bank         Grocery Store
# 46                        Bank                 Hotel
# 47            Sushi Restaurant    Italian Restaurant
# 56          Turkish Restaurant         Women's Store
# 60              Discount Store         Grocery Store
# 63           Convenience Store              Bus Line
# 65       Vietnamese Restaurant               Brewery
# 67           Food & Drink Shop      Department Store
# 70   Middle Eastern Restaurant          Intersection
# 71   Middle Eastern Restaurant           Auto Garage
# 74                Liquor Store                   Pub
# 77               Women's Store          Dance Studio
# 89              Sandwich Place          Liquor Store
# 90           Indian Restaurant           Pizza Place
# 93                Skating Rink        Sandwich Place
# 102             Sandwich Place        Discount Store
#
#            6th Most Common Venue 7th Most Common Venue  \
# 25                   Candy Store            Restaurant
# 29                           Gym           Gas Station
# 46                 Women's Store                 Diner
# 47             Fish & Chips Shop               Brewery
# 56   Eastern European Restaurant             Drugstore
# 60            Airport Food Court  Colombian Restaurant
# 63              Department Store     Electronics Store
# 65              Department Store          Dessert Shop
# 67                Sandwich Place                  Park
# 70                Sandwich Place           Pizza Place
# 71              Department Store     Electronics Store
# 74                          Park          Burger Joint
# 77   Eastern European Restaurant             Drugstore
# 89                      Pharmacy            Beer Store
# 90            Chinese Restaurant          Camera Store
# 93                   Coffee Shop               Dog Run
# 102                Burrito Place          Burger Joint
#
#            8th Most Common Venue      9th Most Common Venue  \
# 25            Italian Restaurant                  Nightclub
# 29          Fast Food Restaurant               Liquor Store
# 46                  Dessert Shop         Dim Sum Restaurant
# 47                Ice Cream Shop                 Restaurant
# 56                    Donut Shop                    Dog Run
# 60            Falafel Restaurant                Event Space
# 63   Eastern European Restaurant                  Drugstore
# 65            Dim Sum Restaurant                      Diner
# 67                  Concert Hall               Dessert Shop
# 70                   Coffee Shop              Deli / Bodega
# 71   Eastern European Restaurant                  Drugstore
# 74                   Shoe Repair  Middle Eastern Restaurant
# 77                    Donut Shop                    Dog Run
# 89          Fast Food Restaurant        Japanese Restaurant
# 90                Sandwich Place             Discount Store
# 93                    Donut Shop        Distribution Center
# 102              Supplement Shop                     Bakery
#
#           10th Most Common Venue
# 25                   Coffee Shop
# 29     Middle Eastern Restaurant
# 46           Distribution Center
# 47             Food & Drink Shop
# 56           Distribution Center
# 60                   Escape Room
# 63                    Donut Shop
# 65                Discount Store
# 67   Eastern European Restaurant
# 70                     Drugstore
# 71                    Donut Shop
# 74                   Flower Shop
# 77           Distribution Center
# 89                   Pizza Place
# 90                  Burger Joint
# 93                  Dance Studio
# 102         Fast Food Restaurant

# %% [markdown]
# <h4> Cluster 5

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#      Neighborhood  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 6  Malvern, Rouge             4.0  Fast Food Restaurant         Women's Store
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 6    Falafel Restaurant           Escape Room     Electronics Store
#
#          6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 6  Eastern European Restaurant             Drugstore            Donut Shop
#
#   9th Most Common Venue 10th Most Common Venue
# 6               Dog Run    Distribution Center

# %% [markdown]
# <h4> Cluster 6

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 5, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                 Neighborhood  Cluster Labels 1st Most Common Venue  \
# 45  York Mills, Silver Hills             5.0                  Park
# 52   Willowdale, Newtonbrook             5.0                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 45         Women's Store          Dance Studio     Electronics Store
# 52         Women's Store          Dance Studio     Electronics Store
#
#           5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 45  Eastern European Restaurant             Drugstore            Donut Shop
# 52  Eastern European Restaurant             Drugstore            Donut Shop
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 45               Dog Run   Distribution Center         Discount Store
# 52               Dog Run   Distribution Center         Discount Store

# %% [markdown]
# <h4> Cluster 7

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 6, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                                           Neighborhood  Cluster Labels  \
# 1                                     Victoria Village             6.0
# 2                            Regent Park, Harbourfront             6.0
# 3                     Lawrence Manor, Lawrence Heights             6.0
# 4                        Ontario Provincial Government             6.0
# 7                                      Don Mills North             6.0
# 8                      Parkview Hill, Woodbine Gardens             6.0
# 9                             Garden District, Ryerson             6.0
# 11   West Deane Park, Princess Gardens, Martin Grov...             6.0
# 12              Rouge Hill, Port Union, Highland Creek             6.0
# 13                                     Don Mills South             6.0
# 14                                    Woodbine Heights             6.0
# 15                                      St. James Town             6.0
# 17   Eringate, Bloordale Gardens, Old Burnhamthorpe...             6.0
# 18                   Guildwood, Morningside, West Hill             6.0
# 19                                         The Beaches             6.0
# 20                                         Berczy Park             6.0
# 22                                              Woburn             6.0
# 23                                             Leaside             6.0
# 24                                  Central Bay Street             6.0
# 26                                           Cedarbrae             6.0
# 27                                   Hillcrest Village             6.0
# 28     Bathurst Manor, Wilson Heights, Downsview North             6.0
# 30                            Richmond, Adelaide, King             6.0
# 31                        Dufferin, Dovercourt Village             6.0
# 33                        Fairview, Henry Farm, Oriole             6.0
# 34                     Northwood Park, York University             6.0
# 36   Harbourfront East, Union Station, Toronto Islands             6.0
# 37                            Little Portugal, Trinity             6.0
# 38         Kennedy Park, Ionview, East Birchmount Park             6.0
# 39                                     Bayview Village             6.0
# ..                                                 ...             ...
# 44                     Golden Mile, Clairlea, Oakridge             6.0
# 48                      Commerce Court, Victoria Hotel             6.0
# 49            North Park, Maple Leaf Park, Upwood Park             6.0
# 51     Cliffside, Cliffcrest, Scarborough Village West             6.0
# 54                                     Studio District             6.0
# 55                   Bedford Park, Lawrence Manor East             6.0
# 58                         Birch Cliff, Cliffside West             6.0
# 59                                    Willowdale South             6.0
# 68                            Forest Hill North & West             6.0
# 69                       High Park, The Junction South             6.0
# 72                                     Willowdale West             6.0
# 73                                  North Toronto West             6.0
# 75                              Parkdale, Roncesvalles             6.0
# 76                                      Enclave of L4W             6.0
# 78                                           Agincourt             6.0
# 79                                          Davisville             6.0
# 80                      University of Toronto, Harbord             6.0
# 81                                  Runnymede, Swansea             6.0
# 82             Clarks Corners, Tam O'Shanter, Sullivan             6.0
# 84           Kensington Market, Chinatown, Grange Park             6.0
# 86   Summerhill West, Rathnelly, South Hill, Forest...             6.0
# 87   CN Tower, King and Spadina, Railway Lands, Har...             6.0
# 88        New Toronto, Mimico South, Humber Bay Shores             6.0
# 92                                      Enclave of M5E             6.0
# 94   Clairville, Humberwood, Woodbine Downs, West H...             6.0
# 96                         St. James Town, Cabbagetown             6.0
# 97              First Canadian Place, Underground city             6.0
# 98       The Kingsway, Montgomery Road, Old Mill North             6.0
# 99                                Church and Wellesley             6.0
# 100                                     Enclave of M4L             6.0
#
#           1st Most Common Venue      2nd Most Common Venue  \
# 1                  Intersection      Portuguese Restaurant
# 2                   Coffee Shop                     Bakery
# 3                Clothing Store     Furniture / Home Store
# 4                   Coffee Shop           Sushi Restaurant
# 7                           Gym       Caribbean Restaurant
# 8                   Pizza Place       Gym / Fitness Center
# 9                          Café             Clothing Store
# 11                       Bakery  Middle Eastern Restaurant
# 12   Construction & Landscaping                        Bar
# 13                          Gym                 Restaurant
# 14                 Skating Rink                Video Store
# 15                         Café             Farmers Market
# 17                     Pharmacy          Convenience Store
# 18                 Intersection                 Restaurant
# 19                          Pub          Health Food Store
# 20                 Cocktail Bar         Seafood Restaurant
# 22                  Coffee Shop               Soccer Field
# 23          Sporting Goods Shop                Coffee Shop
# 24                  Coffee Shop         Italian Restaurant
# 26              Thai Restaurant                Gas Station
# 27                         Pool                Golf Course
# 28                         Bank                Coffee Shop
# 30                         Café                Coffee Shop
# 31                       Bakery                   Pharmacy
# 33                  Coffee Shop             Clothing Store
# 34           Falafel Restaurant     Furniture / Home Store
# 36                        Plaza                      Hotel
# 37                          Bar           Asian Restaurant
# 38             Department Store                Coffee Shop
# 39                         Café         Chinese Restaurant
# ..                          ...                        ...
# 44                     Bus Line                     Bakery
# 48                         Café        Japanese Restaurant
# 49             Basketball Court                     Bakery
# 51                        Motel        American Restaurant
# 54                  Coffee Shop        American Restaurant
# 55               Sandwich Place                Coffee Shop
# 58                         Café            College Stadium
# 59             Ramen Restaurant                       Café
# 68             Sushi Restaurant              Jewelry Store
# 69           Mexican Restaurant                       Café
# 72                  Pizza Place                Coffee Shop
# 73               Clothing Store                Coffee Shop
# 75               Breakfast Spot                  Gift Shop
# 76                  Coffee Shop                      Hotel
# 78                       Lounge             Breakfast Spot
# 79                 Dessert Shop                Pizza Place
# 80                         Café                  Bookstore
# 81                         Café                Pizza Place
# 82                  Pizza Place       Fast Food Restaurant
# 84                         Café                     Bakery
# 86                  Coffee Shop         Light Rail Station
# 87               Airport Lounge              Boat or Ferry
# 88                         Café               Liquor Store
# 92               Farmers Market               Cocktail Bar
# 94                          Bar        Rental Car Location
# 96           Italian Restaurant                       Café
# 97                         Café                Coffee Shop
# 98                         Pool                      River
# 99                    Bookstore                 Hobby Shop
# 100        Gym / Fitness Center                        Spa
#
#          3rd Most Common Venue        4th Most Common Venue  \
# 1                  Coffee Shop            French Restaurant
# 2                         Park               Breakfast Spot
# 3            Accessories Store                  Event Space
# 4                          Gym                   Hobby Shop
# 7                 Dessert Shop          Japanese Restaurant
# 8           Athletics & Sports                         Café
# 9             Ramen Restaurant                  Pizza Place
# 11               Women's Store           Falafel Restaurant
# 12               Women's Store                 Dessert Shop
# 13                 Coffee Shop                    Bike Shop
# 14                 Curling Ice                 Intersection
# 15                   Gastropub                  Coffee Shop
# 17                Liquor Store                   Beer Store
# 18           Electronics Store               Breakfast Spot
# 19                       Trail                Women's Store
# 20                 Coffee Shop                     Beer Bar
# 22       Korean BBQ Restaurant                Women's Store
# 23                        Bank             Sushi Restaurant
# 24                        Café                  Yoga Studio
# 26            Hakka Restaurant           Athletics & Sports
# 27        Fast Food Restaurant     Mediterranean Restaurant
# 28                 Pizza Place                Deli / Bodega
# 30         American Restaurant         Gym / Fitness Center
# 31                   Pet Store                  Music Venue
# 33                   Juice Bar                         Bank
# 34                 Coffee Shop        Vietnamese Restaurant
# 36                        Park                         Café
# 37       Vietnamese Restaurant                  Yoga Studio
# 38                  Hobby Shop            Convenience Store
# 39                        Bank          Japanese Restaurant
# ..                         ...                          ...
# 44                Soccer Field               Ice Cream Shop
# 48                  Restaurant                    Gastropub
# 49                        Park                        Trail
# 51                Intersection                Deli / Bodega
# 54                      Bakery                         Café
# 55          Italian Restaurant                     Pharmacy
# 58       General Entertainment                 Skating Rink
# 59                 Coffee Shop                  Pizza Place
# 68                       Trail                     Bus Line
# 69         Arts & Crafts Store              Thai Restaurant
# 72              Discount Store                  Supermarket
# 73        Gym / Fitness Center           Italian Restaurant
# 75               Movie Theater  Eastern European Restaurant
# 76   Middle Eastern Restaurant                          Gym
# 78              Clothing Store    Latin American Restaurant
# 79          Italian Restaurant             Sushi Restaurant
# 80                         Bar          Japanese Restaurant
# 81            Sushi Restaurant                  Coffee Shop
# 82                    Pharmacy           Chinese Restaurant
# 84       Vietnamese Restaurant         Caribbean Restaurant
# 86            Sushi Restaurant        Vietnamese Restaurant
# 87            Sculpture Garden              Harbor / Marina
# 88                  Hobby Shop                   Restaurant
# 92                    Beer Bar           Seafood Restaurant
# 94                   Drugstore                Garden Center
# 96                  Restaurant                       Bakery
# 97                  Restaurant           Seafood Restaurant
# 98               Women's Store                 Dance Studio
# 99                Dance Studio             Sushi Restaurant
# 100              Auto Workshop                      Brewery
#
#           5th Most Common Venue        6th Most Common Venue  \
# 1                  Hockey Arena                        Diner
# 2          Gym / Fitness Center                Historic Site
# 3                      Boutique        Vietnamese Restaurant
# 4                           Bar                     Beer Bar
# 7                          Café                 Concert Hall
# 8                Breakfast Spot                  Flea Market
# 9                  Burger Joint          Japanese Restaurant
# 11                  Escape Room            Electronics Store
# 12                  Event Space                  Escape Room
# 13                  Art Gallery           Dim Sum Restaurant
# 14                     Bus Stop                         Park
# 15          Japanese Restaurant              Thai Restaurant
# 17               Shopping Plaza                         Café
# 18                   Donut Shop               Medical Center
# 19               Discount Store             Department Store
# 20               Farmers Market                  Fish Market
# 22             Department Store            Electronics Store
# 23                 Burger Joint                   Sports Bar
# 24           Miscellaneous Shop              Bubble Tea Shop
# 26                       Bakery         Caribbean Restaurant
# 27                      Dog Run                Women's Store
# 28             Sushi Restaurant                  Supermarket
# 30                   Steakhouse                    Speakeasy
# 31                         Bank    Middle Eastern Restaurant
# 33                   Restaurant                      Theater
# 34               Massage Studio         Caribbean Restaurant
# 36                  Salad Place                          Bar
# 37      New American Restaurant                       Bistro
# 38                Women's Store                  Escape Room
# 39             Department Store                  Escape Room
# ..                          ...                          ...
# 44                         Park                  Bus Station
# 48                  Coffee Shop          American Restaurant
# 49   Construction & Landscaping                      Dog Run
# 51                  Escape Room            Electronics Store
# 54         Gym / Fitness Center                    Gastropub
# 55                          Pub                    Juice Bar
# 58                 Dance Studio  Eastern European Restaurant
# 59          Arts & Crafts Store                   Restaurant
# 68                Women's Store             Department Store
# 69                Grocery Store          Fried Chicken Joint
# 72                      Butcher                     Pharmacy
# 73           Salon / Barbershop                   Restaurant
# 75           Italian Restaurant                  Coffee Shop
# 76          Fried Chicken Joint               Sandwich Place
# 78                 Skating Rink             Department Store
# 79                         Café                          Gym
# 80               Sandwich Place                       Bakery
# 81           Italian Restaurant            French Restaurant
# 82                         Bank           Italian Restaurant
# 84                          Bar           Italian Restaurant
# 86                  Pizza Place                 Liquor Store
# 87                      Airport           Airport Food Court
# 88           Mexican Restaurant                  Pizza Place
# 92                     Creperie                         Café
# 94                   Truck Stop                 Dessert Shop
# 96                  Coffee Shop                    Gift Shop
# 97                        Hotel         Gym / Fitness Center
# 98            Electronics Store  Eastern European Restaurant
# 99               Ice Cream Shop            Indian Restaurant
# 100               Burrito Place                   Comic Shop
#
#            7th Most Common Venue        8th Most Common Venue  \
# 1                  Deli / Bodega             Department Store
# 2                     Restaurant                          Pub
# 3                    Coffee Shop          Distribution Center
# 4                            Spa                Smoothie Shop
# 7               Department Store            Electronics Store
# 8                           Bank                 Intersection
# 9            Sporting Goods Shop            Electronics Store
# 11   Eastern European Restaurant                    Drugstore
# 12             Electronics Store  Eastern European Restaurant
# 13                   Supermarket               Sandwich Place
# 14                    Beer Store                    Drugstore
# 15                       Theater           Italian Restaurant
# 17                   Pizza Place                    Pet Store
# 18            Mexican Restaurant                         Bank
# 19                  Dessert Shop           Dim Sum Restaurant
# 20                     Jazz Club           Basketball Stadium
# 22   Eastern European Restaurant                    Drugstore
# 23                Breakfast Spot            Fish & Chips Shop
# 24                           Spa                 Dessert Shop
# 26                          Bank          Fried Chicken Joint
# 27                 Deli / Bodega  Eastern European Restaurant
# 28                   Bridal Shop                        Diner
# 30                    Smoke Shop           Seafood Restaurant
# 31                           Bar                  Supermarket
# 33                  Liquor Store                Shopping Mall
# 34                           Bar          Distribution Center
# 36                     Roof Deck           Italian Restaurant
# 37                       Brewery                         Café
# 38             Electronics Store  Eastern European Restaurant
# 39             Electronics Store  Eastern European Restaurant
# ..                           ...                          ...
# 44                  Intersection                Metro Station
# 48                         Hotel           Seafood Restaurant
# 49                         Diner               Discount Store
# 51   Eastern European Restaurant                    Drugstore
# 54                     Pet Store                         Park
# 55                       Butcher         Fast Food Restaurant
# 58                     Drugstore                   Donut Shop
# 59          Fast Food Restaurant             Sushi Restaurant
# 68             Electronics Store  Eastern European Restaurant
# 69                   Music Venue    Cajun / Creole Restaurant
# 72                     Drugstore                   Donut Shop
# 73           Rental Car Location                    Pet Store
# 75                     Bookstore                      Dog Run
# 76      Mediterranean Restaurant                Burrito Place
# 78             Electronics Store  Eastern European Restaurant
# 79                   Coffee Shop               Sandwich Place
# 80                    Restaurant                 Dessert Shop
# 81                  Dessert Shop          Indie Movie Theater
# 82           Fried Chicken Joint            Convenience Store
# 84                     Jazz Club                  Fish Market
# 86                    Restaurant                  Supermarket
# 87                  Airport Gate              Airport Service
# 88          Fast Food Restaurant                  Flower Shop
# 92                        Museum                   Restaurant
# 94            Dim Sum Restaurant                        Diner
# 96                    Beer Store                  Snack Place
# 97                   Art Gallery                    Speakeasy
# 98                     Drugstore                   Donut Shop
# 99           Martial Arts School                   Restaurant
# 100               Farmers Market         Fast Food Restaurant
#
#            9th Most Common Venue     10th Most Common Venue
# 1                   Dessert Shop         Dim Sum Restaurant
# 2          Performing Arts Venue         Mexican Restaurant
# 3             Dim Sum Restaurant                      Diner
# 4                  Burrito Place             Sandwich Place
# 7    Eastern European Restaurant                  Drugstore
# 8                       Pharmacy                  Gastropub
# 9        New American Restaurant                  Bookstore
# 11                    Donut Shop                    Dog Run
# 12                     Drugstore                 Donut Shop
# 13                Discount Store           Asian Restaurant
# 14                    Donut Shop                    Dog Run
# 15                    Restaurant                       Park
# 17                   Coffee Shop               Dessert Shop
# 18           Rental Car Location               Dessert Shop
# 19                         Diner                    Dog Run
# 20                Breakfast Spot               Liquor Store
# 22                    Donut Shop                    Dog Run
# 23                   Supermarket             Sandwich Place
# 24              Department Store             Sandwich Place
# 26                  Dessert Shop         Dim Sum Restaurant
# 27                     Drugstore                 Donut Shop
# 28                 Shopping Mall             Sandwich Place
# 30            Salon / Barbershop                 Restaurant
# 31                          Café                       Park
# 33             Electronics Store               Burger Joint
# 34            Dim Sum Restaurant                      Diner
# 36                   Supermarket         Basketball Stadium
# 37                   Record Shop               Cocktail Bar
# 38                     Drugstore                 Donut Shop
# 39                     Drugstore                 Donut Shop
# ..                           ...                        ...
# 44            Dim Sum Restaurant                      Diner
# 48                 Deli / Bodega                Tailor Shop
# 49           Distribution Center              Women's Store
# 51                    Donut Shop                    Dog Run
# 54     Middle Eastern Restaurant  Latin American Restaurant
# 55                          Café          Indian Restaurant
# 58                       Dog Run        Distribution Center
# 59                          Bank             Ice Cream Shop
# 68                     Drugstore                 Donut Shop
# 69                         Diner             Discount Store
# 72   Eastern European Restaurant               Dance Studio
# 73                          Park         Mexican Restaurant
# 75                  Dessert Shop                        Bar
# 76                  Intersection        American Restaurant
# 78                     Drugstore                 Donut Shop
# 79             Indian Restaurant                    Brewery
# 80            Italian Restaurant               Noodle House
# 81             Fish & Chips Shop                   Tea Room
# 82               Thai Restaurant               Noodle House
# 84            Belgian Restaurant             Farmers Market
# 86                           Pub        American Restaurant
# 87              Airport Terminal                   Boutique
# 88                        Bakery                   Pharmacy
# 92               Thai Restaurant               Concert Hall
# 94                Discount Store              Women's Store
# 96                       Butcher       Caribbean Restaurant
# 97           Japanese Restaurant                 Steakhouse
# 98                       Dog Run        Distribution Center
# 99            Italian Restaurant                   Beer Bar
# 100                       Garden              Garden Center
#
# [63 rows x 12 columns]

# %% [markdown]
# <h4> Cluster 8

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 7, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                                           Neighborhood  Cluster Labels  \
# 53                                   Downsview Central             7.0
# 57                                    Humberlea, Emery             7.0
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...             7.0
#
#     1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 53         Baseball Field            Food Truck         Women's Store
# 57         Baseball Field         Women's Store        Farmers Market
# 101        Baseball Field         Women's Store        Farmers Market
#
#     4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 53     Falafel Restaurant           Escape Room     Electronics Store
# 57            Event Space           Escape Room     Electronics Store
# 101           Event Space           Escape Room     Electronics Store
#
#            7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 53   Eastern European Restaurant             Drugstore            Donut Shop
# 57   Eastern European Restaurant             Drugstore            Donut Shop
# 101  Eastern European Restaurant             Drugstore            Donut Shop
#
#     10th Most Common Venue
# 53                 Dog Run
# 57                 Dog Run
# 101                Dog Run

# %% [markdown]
# <h4> Cluster 9

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 8, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#    Neighborhood  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 64       Weston             8.0     Convenience Store         Women's Store
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 64         Deli / Bodega           Escape Room     Electronics Store
#
#           6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 64  Eastern European Restaurant             Drugstore            Donut Shop
#
#    9th Most Common Venue 10th Most Common Venue
# 64               Dog Run    Distribution Center

# %% [markdown]
# <h4>Visualize the findings of Ashrafieh Zone Number: 62 on a map

# %%
venues_map_1 = folium.Map(location=[latitude_1, longitude_1], zoom_start=20) # generate map centred around Ashrafieh

# add Ashrafieh Zone Number:62 as a red circle mark
folium.CircleMarker(
    [latitude_1, longitude_1],
    radius=10,
    popup='Ashrafieh Zone Number: 62',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map_1)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(main_filtered_1.lat, main_filtered_1.lng, main_filtered_1.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map_1)
    
# display map
venues_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_a15c35d51dbe405f81f689aef16b4dbe%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a15c35d51dbe405f81f689aef16b4dbe%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a15c35d51dbe405f81f689aef16b4dbe%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_a15c35d51dbe405f81f689aef16b4dbe%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B33.8860027%2C35.5151357%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2020%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20 ...
